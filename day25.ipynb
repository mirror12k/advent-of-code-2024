# %%
#!/usr/bin/env perl
use strict;
use warnings;
use feature qw/ say current_sub state /;
use Data::Dumper;
use lib '.';
use toolkit;
use graphql;
use adventofcode;
use Carp 'confess';

$Data::Dumper::Sortkeys = 1;
# Out:
# 1

# %%
my $practice_input = qq/#####
.####
.####
.####
.#.#.
.#...
.....

#####
##.##
.#.##
...##
...#.
...#.
.....

.....
#....
#....
#...#
#.#.#
#.###
#####

.....
.....
#.#..
###..
###.#
###.#
#####

.....
.....
.....
#....
#.#..
#.#.#
#####/;
# Out:
# #####
# .####
# .####
# .####
# .#.#.
# .#...
# .....
#
# #####
# ##.##
# .#.##
# ...##
# ...#.
# ...#.
# .....
#
# .....
# #....
# #....
# #...#
# #.#.#
# #.###
# #####
#
# .....
# .....
# #.#..
# ###..
# ###.#
# ###.#
# #####
#
# .....
# .....
# .....
# #....
# #.#..
# #.#.#
# #####

# %%
sub first_incorrect_pin {
    my ($lock, $key) = @_;
    my @lpins = split ',', $lock->{pins};
    my @kpins = split ',', $key->{pins};
    die "assertion failed: does_lock_fit_key lengths dont match: $lock->{pins} vs $key->{pins}" if @lpins != @kpins;
    foreach (0 .. $#lpins) {
        return $_ if $lpins[$_] + $kpins[$_] > 5;
    }
    return;
}
sub process_day25_part1 {
    my ($input) = @_;

    my @schemas = split "\n\n", $input;

    my %groups = group_by sub { $_->{type} },
        map { { type => $_ =~ /\A#/ ? 'lock' : 'key', pins => join ',', map $_-1, map length, map /(#+)/, split "\n" } }
        map { string_2d_map_array transpose_2d parse_2d_map_array($_) }
        @schemas;

    my @solutions;
    foreach my $lock (@{$groups{lock}}) {
        foreach my $key (@{$groups{key}}) {
            my $incorrect = first_incorrect_pin($lock, $key);
            unless (defined $incorrect) {
                say "$lock->{pins} and $key->{pins} fit all columns";
                push @solutions, [ $lock, $key ];
            } else {
                say "$lock->{pins} and $key->{pins} overlap on column $incorrect";
            }
        }
    }
    return scalar @solutions;
}

timer sub {
    say Dumper process_day25_part1($practice_input);
    confirm process_day25_part1($practice_input), 3;
}
# Out:
# 0,5,3,4,3 and 5,0,2,1,3 overlap on column 4
# 0,5,3,4,3 and 4,3,4,0,2 overlap on column 1
# 0,5,3,4,3 and 3,0,2,0,1 fit all columns
# 1,2,0,5,3 and 5,0,2,1,3 overlap on column 0
# 1,2,0,5,3 and 4,3,4,0,2 fit all columns
# 1,2,0,5,3 and 3,0,2,0,1 fit all columns
# $VAR1 = 3;
#
# 0,5,3,4,3 and 5,0,2,1,3 overlap on column 4
# 0,5,3,4,3 and 4,3,4,0,2 overlap on column 1
# 0,5,3,4,3 and 3,0,2,0,1 fit all columns
# 1,2,0,5,3 and 5,0,2,1,3 overlap on column 0
# 1,2,0,5,3 and 4,3,4,0,2 fit all columns
# 1,2,0,5,3 and 3,0,2,0,1 fit all columns
# confirmed: 3
# [time] 0 seconds
# 0
# Subroutine first_incorrect_pin redefined at reply input line 1.
#
# Subroutine process_day25_part1 redefined at reply input line 11.

# %%
my $res;
timer sub {
    my $input = get_challenge('2024/day/25/input');
    $res = process_day25_part1($input);
    say Dumper $res;
    # confirm $res, 56278503604006;
};
# Out:
# 5,0,2,0,3 and 5,1,2,1,4 overlap on column 0
# 5,0,2,0,3 and 2,5,2,1,3 overlap on column 0
# 5,0,2,0,3 and 0,5,3,5,4 overlap on column 4
# 5,0,2,0,3 and 0,5,1,4,3 overlap on column 4
# 5,0,2,0,3 and 3,4,5,3,5 overlap on column 0
# 5,0,2,0,3 and 5,3,4,2,0 overlap on column 0
# 5,0,2,0,3 and 0,3,4,2,5 overlap on column 2
# 5,0,2,0,3 and 1,4,0,5,1 overlap on column 0
# 5,0,2,0,3 and 0,1,0,1,4 overlap on column 4
# 5,0,2,0,3 and 1,0,1,0,5 overlap on column 0
# 5,0,2,0,3 and 3,1,3,4,3 overlap on column 0
# 5,0,2,0,3 and 3,1,0,3,2 overlap on column 0
# 5,0,2,0,3 and 4,5,0,2,3 overlap on column 0
# 5,0,2,0,3 and 0,3,1,0,1 fit all columns
# 5,0,2,0,3 and 5,1,5,0,2 overlap on column 0
# 5,0,2,0,3 and 5,1,5,2,0 overlap on column 0
# 5,0,2,0,3 and 3,4,1,5,4 overlap on column 0
# 5,0,2,0,3 and 5,1,4,5,3 overlap on column 0
# 5,0,2,0,3 and 4,5,4,0,1 overlap on column 0
# 5,0,2,0,3 and 2,3,2,5,4 overlap on column 0
# 5,0,2,0,3 and 1,2,0,4,2 overlap on column 0
# 5,0,2,0,3 and 5,4,3,5,2 overlap on column 0
# 5,0,2,0,3 and 1,5,0,2,1 overlap on column 0
# 5,0,2,0,3 and 0,2,0,3,1 fit all columns
# 5,0,2,0,3 and 2,3,1,5,1 overlap on column 0
# 5,0,2,0,3 and 3,2,5,3,1 overlap on column 0
# 5,0,2,0,3 and 5,0,5,3,2 overlap on column 0
# 5,0,2,0,3 and 0,2,3,4,1 fit all columns
# 5,0,2,0,3 and 4,5,4,5,4 overlap on column 0
# 5,0,2,0,3 and 4,3,2,0,3 overlap on column 0
# 5,0,2,0,3 and 3,2,5,0,2 overlap on column 0
# 5,0,2,0,3 and 5,1,2,5,3 overlap on column 0
# 5,0,2,0,3 and 5,4,1,4,0 overlap on column 0
# 5,0,2,0,3 and 1,0,5,3,2 overlap on column 0
# 5,0,2,0,3 and 4,3,5,4,3 overlap on column 0
# 5,0,2,0,3 and 2,5,4,0,3 overlap on column 0
# 5,0,2,0,3 and 0,2,5,0,2 overlap on column 2
# 5,0,2,0,3 and 4,0,5,1,0 overlap on column 0
# 5,0,2,0,3 and 1,2,4,5,3 overlap on column 0
# 5,0,2,0,3 and 3,1,3,5,3 overlap on column 0
# 5,0,2,0,3 and 3,2,4,1,2 overlap on column 0
# 5,0,2,0,3 and 2,4,0,3,0 overlap on column 0
# 5,0,2,0,3 and 3,5,0,4,0 overlap on column 0
# 5,0,2,0,3 and 3,5,4,5,2 overlap on column 0
# 5,0,2,0,3 and 1,2,5,2,0 overlap on column 0
# 5,0,2,0,3 and 4,0,4,1,2 overlap on column 0
# 5,0,2,0,3 and 3,4,0,3,0 overlap on column 0
# 5,0,2,0,3 and 5,1,5,4,3 overlap on column 0
# 5,0,2,0,3 and 4,5,4,5,2 overlap on column 0
# 5,0,2,0,3 and 4,2,0,3,5 overlap on column 0
# 5,0,2,0,3 and 2,3,4,5,2 overlap on column 0
# 5,0,2,0,3 and 3,4,1,5,2 overlap on column 0
# 5,0,2,0,3 and 0,1,3,2,0 fit all columns
# 5,0,2,0,3 and 4,3,5,1,0 overlap on column 0
# 5,0,2,0,3 and 3,0,1,5,3 overlap on column 0
# 5,0,2,0,3 and 3,1,5,3,4 overlap on column 0
# 5,0,2,0,3 and 1,0,4,1,5 overlap on column 0
# 5,0,2,0,3 and 1,0,1,0,4 overlap on column 0
# 5,0,2,0,3 and 3,2,3,1,0 overlap on column 0
# 5,0,2,0,3 and 0,5,3,4,3 overlap on column 4
# 5,0,2,0,3 and 4,1,2,5,0 overlap on column 0
# 5,0,2,0,3 and 4,3,4,2,3 overlap on column 0
# 5,0,2,0,3 and 1,0,1,5,2 overlap on column 0
# 5,0,2,0,3 and 0,2,4,5,1 overlap on column 2
# 5,0,2,0,3 and 3,4,5,3,0 overlap on column 0
# 5,0,2,0,3 and 0,2,3,1,5 overlap on column 4
# 5,0,2,0,3 and 1,2,0,5,2 overlap on column 0
# 5,0,2,0,3 and 4,5,4,1,5 overlap on column 0
# 5,0,2,0,3 and 0,3,5,3,5 overlap on column 2
# 5,0,2,0,3 and 4,0,4,5,2 overlap on column 0
# 5,0,2,0,3 and 5,3,5,1,2 overlap on column 0
# 5,0,2,0,3 and 1,3,5,1,5 overlap on column 0
# 5,0,2,0,3 and 0,2,3,2,0 fit all columns
# 5,0,2,0,3 and 5,3,2,4,3 overlap on column 0
# 5,0,2,0,3 and 5,1,5,1,3 overlap on column 0
# 5,0,2,0,3 and 3,5,4,1,0 overlap on column 0
# 5,0,2,0,3 and 1,2,4,5,1 overlap on column 0
# 5,0,2,0,3 and 0,1,3,5,3 overlap on column 4
# 5,0,2,0,3 and 5,3,1,0,2 overlap on column 0
# 5,0,2,0,3 and 3,0,5,1,3 overlap on column 0
# 5,0,2,0,3 and 5,3,5,2,5 overlap on column 0
# 5,0,2,0,3 and 5,3,4,3,1 overlap on column 0
# 5,0,2,0,3 and 1,0,5,3,1 overlap on column 0
# 5,0,2,0,3 and 2,5,2,0,1 overlap on column 0
# 5,0,2,0,3 and 0,1,2,3,4 overlap on column 4
# 5,0,2,0,3 and 0,4,0,3,0 fit all columns
# 5,0,2,0,3 and 3,1,3,1,3 overlap on column 0
# 5,0,2,0,3 and 1,4,5,2,3 overlap on column 0
# 5,0,2,0,3 and 3,0,2,5,2 overlap on column 0
# 5,0,2,0,3 and 3,1,0,5,2 overlap on column 0
# 5,0,2,0,3 and 5,2,4,1,5 overlap on column 0
# 5,0,2,0,3 and 1,3,5,2,1 overlap on column 0
# 5,0,2,0,3 and 1,5,4,5,3 overlap on column 0
# 5,0,2,0,3 and 3,1,4,1,0 overlap on column 0
# 5,0,2,0,3 and 5,2,1,0,5 overlap on column 0
# 5,0,2,0,3 and 4,2,1,3,0 overlap on column 0
# 5,0,2,0,3 and 4,2,5,3,0 overlap on column 0
# 5,0,2,0,3 and 1,0,3,1,4 overlap on column 0
# 5,0,2,0,3 and 4,3,1,3,5 overlap on column 0
# 5,0,2,0,3 and 3,5,3,5,0 overlap on column 0
# 5,0,2,0,3 and 0,3,0,2,4 overlap on column 4
# 5,0,2,0,3 and 1,0,5,3,0 overlap on column 0
# 5,0,2,0,3 and 3,1,5,2,4 overlap on column 0
# 5,0,2,0,3 and 1,5,1,0,2 overlap on column 0
# 5,0,2,0,3 and 0,5,1,4,1 fit all columns
# 5,0,2,0,3 and 2,5,0,2,4 overlap on column 0
# 5,0,2,0,3 and 3,2,4,2,3 overlap on column 0
# 5,0,2,0,3 and 1,5,1,2,5 overlap on column 0
# 5,0,2,0,3 and 0,5,4,2,1 overlap on column 2
# 5,0,2,0,3 and 5,3,0,3,1 overlap on column 0
# 5,0,2,0,3 and 5,1,4,2,0 overlap on column 0
# 5,0,2,0,3 and 3,4,3,1,2 overlap on column 0
# 5,0,2,0,3 and 0,1,5,1,0 overlap on column 2
# 5,0,2,0,3 and 5,4,5,3,0 overlap on column 0
# 5,0,2,0,3 and 2,1,0,4,0 overlap on column 0
# 5,0,2,0,3 and 4,5,1,2,1 overlap on column 0
# 5,0,2,0,3 and 2,5,1,5,0 overlap on column 0
# 5,0,2,0,3 and 0,1,2,1,3 overlap on column 4
# 5,0,2,0,3 and 4,1,5,3,4 overlap on column 0
# 5,0,2,0,3 and 0,5,3,1,4 overlap on column 4
# 5,0,2,0,3 and 4,1,5,0,1 overlap on column 0
# 5,0,2,0,3 and 3,5,2,4,5 overlap on column 0
# 5,0,2,0,3 and 3,5,3,5,4 overlap on column 0
# 5,0,2,0,3 and 1,5,1,0,1 overlap on column 0
# 5,0,2,0,3 and 1,3,0,2,1 overlap on column 0
# 5,0,2,0,3 and 5,0,3,1,4 overlap on column 0
# 5,0,2,0,3 and 4,1,5,3,2 overlap on column 0
# 5,0,2,0,3 and 4,2,3,4,5 overlap on column 0
# 5,0,2,0,3 and 3,2,0,2,0 overlap on column 0
# 5,0,2,0,3 and 3,5,1,2,3 overlap on column 0
# 5,0,2,0,3 and 1,2,4,1,3 overlap on column 0
# 5,0,2,0,3 and 1,5,0,3,4 overlap on column 0
# 5,0,2,0,3 and 3,1,0,3,5 overlap on column 0
# 5,0,2,0,3 and 5,3,4,2,3 overlap on column 0
# 5,0,2,0,3 and 1,5,2,5,2 overlap on column 0
# 5,0,2,0,3 and 4,5,0,3,4 overlap on column 0
# 5,0,2,0,3 and 4,2,3,4,2 overlap on column 0
# 5,0,2,0,3 and 2,3,1,2,4 overlap on column 0
# 5,0,2,0,3 and 3,5,1,5,0 overlap on column 0
# 5,0,2,0,3 and 5,2,3,1,3 overlap on column 0
# 5,0,2,0,3 and 0,3,4,1,2 overlap on column 2
# 5,0,2,0,3 and 4,0,1,3,4 overlap on column 0
# 5,0,2,0,3 and 2,5,1,4,0 overlap on column 0
# 5,0,2,0,3 and 2,1,4,3,2 overlap on column 0
# 5,0,2,0,3 and 0,1,2,4,1 fit all columns
# 5,0,2,0,3 and 0,1,4,0,3 overlap on column 2
# 5,0,2,0,3 and 1,5,3,0,4 overlap on column 0
# 5,0,2,0,3 and 2,4,0,2,0 overlap on column 0
# 5,0,2,0,3 and 3,5,0,4,1 overlap on column 0
# 5,0,2,0,3 and 0,2,3,2,3 overlap on column 4
# 5,0,2,0,3 and 3,2,1,0,4 overlap on column 0
# 5,0,2,0,3 and 1,3,4,2,3 overlap on column 0
# 5,0,2,0,3 and 1,0,4,3,0 overlap on column 0
# 5,0,2,0,3 and 0,1,4,1,4 overlap on column 2
# 5,0,2,0,3 and 5,1,0,1,3 overlap on column 0
# 5,0,2,0,3 and 2,4,2,1,3 overlap on column 0
# 5,0,2,0,3 and 3,4,3,2,4 overlap on column 0
# 5,0,2,0,3 and 3,1,0,5,1 overlap on column 0
# 5,0,2,0,3 and 0,4,5,0,2 overlap on column 2
# 5,0,2,0,3 and 4,5,4,5,1 overlap on column 0
# 5,0,2,0,3 and 5,1,4,3,4 overlap on column 0
# 5,0,2,0,3 and 4,1,5,3,0 overlap on column 0
# 5,0,2,0,3 and 4,1,3,5,0 overlap on column 0
# 5,0,2,0,3 and 0,4,1,3,5 overlap on column 4
# 5,0,2,0,3 and 0,1,5,3,5 overlap on column 2
# 5,0,2,0,3 and 5,1,0,3,4 overlap on column 0
# 5,0,2,0,3 and 0,5,1,0,5 overlap on column 4
# 5,0,2,0,3 and 5,0,4,0,1 overlap on column 0
# 5,0,2,0,3 and 2,4,0,3,1 overlap on column 0
# 5,0,2,0,3 and 5,3,5,1,3 overlap on column 0
# 5,0,2,0,3 and 1,0,3,2,5 overlap on column 0
# 5,0,2,0,3 and 5,1,5,3,1 overlap on column 0
# 5,0,2,0,3 and 0,3,1,2,4 overlap on column 4
# 5,0,2,0,3 and 2,0,4,0,2 overlap on column 0
# 5,0,2,0,3 and 5,1,3,1,3 overlap on column 0
# 5,0,2,0,3 and 5,0,4,1,4 overlap on column 0
# 5,0,2,0,3 and 1,4,5,0,4 overlap on column 0
# 5,0,2,0,3 and 5,2,1,2,0 overlap on column 0
# 5,0,2,0,3 and 1,5,4,3,0 overlap on column 0
# 5,0,2,0,3 and 4,3,5,0,3 overlap on column 0
# 5,0,2,0,3 and 5,4,1,0,5 overlap on column 0
# 5,0,2,0,3 and 3,1,4,0,3 overlap on column 0
# 5,0,2,0,3 and 3,4,3,4,1 overlap on column 0
# 5,0,2,0,3 and 1,4,0,4,2 overlap on column 0
# 5,0,2,0,3 and 1,5,3,2,1 overlap on column 0
# 5,0,2,0,3 and 3,5,1,5,3 overlap on column 0
# 5,0,2,0,3 and 5,4,0,4,0 overlap on column 0
# 5,0,2,0,3 and 3,2,4,2,5 overlap on column 0
# 5,0,2,0,3 and 2,1,4,1,0 overlap on column 0
# 5,0,2,0,3 and 2,5,3,5,3 overlap on column 0
# 5,0,2,0,3 and 2,0,2,0,4 overlap on column 0
# 5,0,2,0,3 and 5,0,4,2,0 overlap on column 0
# 5,0,2,0,3 and 3,0,1,0,1 overlap on column 0
# 5,0,2,0,3 and 1,0,5,4,2 overlap on column 0
# 5,0,2,0,3 and 2,0,1,0,3 overlap on column 0
# 5,0,2,0,3 and 3,5,4,2,1 overlap on column 0
# 5,0,2,0,3 and 5,2,1,5,0 overlap on column 0
# 5,0,2,0,3 and 3,1,2,4,1 overlap on column 0
# 5,0,2,0,3 and 3,0,4,2,1 overlap on column 0
# 5,0,2,0,3 and 0,5,2,0,5 overlap on column 4
# 5,0,2,0,3 and 4,5,0,1,5 overlap on column 0
# 5,0,2,0,3 and 0,3,0,3,1 fit all columns
# 5,0,2,0,3 and 1,3,2,3,0 overlap on column 0
# 5,0,2,0,3 and 3,2,1,2,5 overlap on column 0
# 5,0,2,0,3 and 0,3,2,0,5 overlap on column 4
# 5,0,2,0,3 and 0,4,3,5,2 fit all columns
# 5,0,2,0,3 and 1,0,5,1,0 overlap on column 0
# 5,0,2,0,3 and 5,0,3,5,2 overlap on column 0
# 5,0,2,0,3 and 5,0,1,4,2 overlap on column 0
# 5,0,2,0,3 and 0,2,3,1,3 overlap on column 4
# 5,0,2,0,3 and 4,0,1,4,3 overlap on column 0
# 5,0,2,0,3 and 4,3,5,0,4 overlap on column 0
# 5,0,2,0,3 and 0,5,2,0,3 overlap on column 4
# 5,0,2,0,3 and 0,3,2,5,1 fit all columns
# 5,0,2,0,3 and 2,5,1,4,5 overlap on column 0
# 5,0,2,0,3 and 0,1,5,3,0 overlap on column 2
# 5,0,2,0,3 and 4,3,5,3,0 overlap on column 0
# 5,0,2,0,3 and 0,2,3,0,3 overlap on column 4
# 5,0,2,0,3 and 5,2,3,1,2 overlap on column 0
# 5,0,2,0,3 and 1,2,5,3,1 overlap on column 0
# 5,0,2,0,3 and 2,0,1,4,3 overlap on column 0
# 5,0,2,0,3 and 0,3,0,1,3 overlap on column 4
# 5,0,2,0,3 and 3,2,1,0,2 overlap on column 0
# 5,0,2,0,3 and 1,0,3,1,0 overlap on column 0
# 5,0,2,0,3 and 3,1,3,2,3 overlap on column 0
# 5,0,2,0,3 and 3,1,3,4,5 overlap on column 0
# 5,0,2,0,3 and 2,1,4,5,4 overlap on column 0
# 5,0,2,0,3 and 1,2,0,2,5 overlap on column 0
# 5,0,2,0,3 and 2,1,2,0,4 overlap on column 0
# 5,0,2,0,3 and 5,2,4,5,4 overlap on column 0
# 5,0,2,0,3 and 3,5,1,4,5 overlap on column 0
# 5,0,2,0,3 and 3,2,0,5,1 overlap on column 0
# 5,0,2,0,3 and 0,3,2,4,3 overlap on column 4
# 5,0,2,0,3 and 0,5,4,1,0 overlap on column 2
# 5,0,2,0,3 and 5,1,3,2,0 overlap on column 0
# 5,0,2,0,3 and 3,4,1,4,0 overlap on column 0
# 5,0,2,0,3 and 2,5,1,0,5 overlap on column 0
# 5,0,2,0,3 and 4,2,3,4,1 overlap on column 0
# 5,0,2,0,3 and 1,2,4,3,0 overlap on column 0
# 5,0,2,0,3 and 1,0,3,0,5 overlap on column 0
# 5,0,2,0,3 and 1,4,0,5,3 overlap on column 0
# 5,0,2,0,3 and 4,0,2,5,1 overlap on column 0
# 5,0,2,0,3 and 4,5,3,0,2 overlap on column 0
# 5,0,2,0,3 and 1,2,5,1,3 overlap on column 0
# 5,0,2,0,3 and 1,3,2,3,4 overlap on column 0
# 5,0,2,0,3 and 0,2,3,5,2 fit all columns
# 5,0,2,0,3 and 4,1,3,0,2 overlap on column 0
# 5,0,2,0,3 and 3,5,3,4,2 overlap on column 0
# 5,0,2,0,3 and 2,0,3,0,3 overlap on column 0
# 5,0,2,0,3 and 3,5,0,3,5 overlap on column 0
# 2,1,0,1,0 and 5,1,2,1,4 overlap on column 0
# 2,1,0,1,0 and 2,5,2,1,3 overlap on column 1
# 2,1,0,1,0 and 0,5,3,5,4 overlap on column 1
# 2,1,0,1,0 and 0,5,1,4,3 overlap on column 1
# 2,1,0,1,0 and 3,4,5,3,5 fit all columns
# 2,1,0,1,0 and 5,3,4,2,0 overlap on column 0
# 2,1,0,1,0 and 0,3,4,2,5 fit all columns
# 2,1,0,1,0 and 1,4,0,5,1 overlap on column 3
# 2,1,0,1,0 and 0,1,0,1,4 fit all columns
# 2,1,0,1,0 and 1,0,1,0,5 fit all columns
# 2,1,0,1,0 and 3,1,3,4,3 fit all columns
# 2,1,0,1,0 and 3,1,0,3,2 fit all columns
# 2,1,0,1,0 and 4,5,0,2,3 overlap on column 0
# 2,1,0,1,0 and 0,3,1,0,1 fit all columns
# 2,1,0,1,0 and 5,1,5,0,2 overlap on column 0
# 2,1,0,1,0 and 5,1,5,2,0 overlap on column 0
# 2,1,0,1,0 and 3,4,1,5,4 overlap on column 3
# 2,1,0,1,0 and 5,1,4,5,3 overlap on column 0
# 2,1,0,1,0 and 4,5,4,0,1 overlap on column 0
# 2,1,0,1,0 and 2,3,2,5,4 overlap on column 3
# 2,1,0,1,0 and 1,2,0,4,2 fit all columns
# 2,1,0,1,0 and 5,4,3,5,2 overlap on column 0
# 2,1,0,1,0 and 1,5,0,2,1 overlap on column 1
# 2,1,0,1,0 and 0,2,0,3,1 fit all columns
# 2,1,0,1,0 and 2,3,1,5,1 overlap on column 3
# 2,1,0,1,0 and 3,2,5,3,1 fit all columns
# 2,1,0,1,0 and 5,0,5,3,2 overlap on column 0
# 2,1,0,1,0 and 0,2,3,4,1 fit all columns
# 2,1,0,1,0 and 4,5,4,5,4 overlap on column 0
# 2,1,0,1,0 and 4,3,2,0,3 overlap on column 0
# 2,1,0,1,0 and 3,2,5,0,2 fit all columns
# 2,1,0,1,0 and 5,1,2,5,3 overlap on column 0
# 2,1,0,1,0 and 5,4,1,4,0 overlap on column 0
# 2,1,0,1,0 and 1,0,5,3,2 fit all columns
# 2,1,0,1,0 and 4,3,5,4,3 overlap on column 0
# 2,1,0,1,0 and 2,5,4,0,3 overlap on column 1
# 2,1,0,1,0 and 0,2,5,0,2 fit all columns
# 2,1,0,1,0 and 4,0,5,1,0 overlap on column 0
# 2,1,0,1,0 and 1,2,4,5,3 overlap on column 3
# 2,1,0,1,0 and 3,1,3,5,3 overlap on column 3
# 2,1,0,1,0 and 3,2,4,1,2 fit all columns
# 2,1,0,1,0 and 2,4,0,3,0 fit all columns
# 2,1,0,1,0 and 3,5,0,4,0 overlap on column 1
# 2,1,0,1,0 and 3,5,4,5,2 overlap on column 1
# 2,1,0,1,0 and 1,2,5,2,0 fit all columns
# 2,1,0,1,0 and 4,0,4,1,2 overlap on column 0
# 2,1,0,1,0 and 3,4,0,3,0 fit all columns
# 2,1,0,1,0 and 5,1,5,4,3 overlap on column 0
# 2,1,0,1,0 and 4,5,4,5,2 overlap on column 0
# 2,1,0,1,0 and 4,2,0,3,5 overlap on column 0
# 2,1,0,1,0 and 2,3,4,5,2 overlap on column 3
# 2,1,0,1,0 and 3,4,1,5,2 overlap on column 3
# 2,1,0,1,0 and 0,1,3,2,0 fit all columns
# 2,1,0,1,0 and 4,3,5,1,0 overlap on column 0
# 2,1,0,1,0 and 3,0,1,5,3 overlap on column 3
# 2,1,0,1,0 and 3,1,5,3,4 fit all columns
# 2,1,0,1,0 and 1,0,4,1,5 fit all columns
# 2,1,0,1,0 and 1,0,1,0,4 fit all columns
# 2,1,0,1,0 and 3,2,3,1,0 fit all columns
# 2,1,0,1,0 and 0,5,3,4,3 overlap on column 1
# 2,1,0,1,0 and 4,1,2,5,0 overlap on column 0
# 2,1,0,1,0 and 4,3,4,2,3 overlap on column 0
# 2,1,0,1,0 and 1,0,1,5,2 overlap on column 3
# 2,1,0,1,0 and 0,2,4,5,1 overlap on column 3
# 2,1,0,1,0 and 3,4,5,3,0 fit all columns
# 2,1,0,1,0 and 0,2,3,1,5 fit all columns
# 2,1,0,1,0 and 1,2,0,5,2 overlap on column 3
# 2,1,0,1,0 and 4,5,4,1,5 overlap on column 0
# 2,1,0,1,0 and 0,3,5,3,5 fit all columns
# 2,1,0,1,0 and 4,0,4,5,2 overlap on column 0
# 2,1,0,1,0 and 5,3,5,1,2 overlap on column 0
# 2,1,0,1,0 and 1,3,5,1,5 fit all columns
# 2,1,0,1,0 and 0,2,3,2,0 fit all columns
# 2,1,0,1,0 and 5,3,2,4,3 overlap on column 0
# 2,1,0,1,0 and 5,1,5,1,3 overlap on column 0
# 2,1,0,1,0 and 3,5,4,1,0 overlap on column 1
# 2,1,0,1,0 and 1,2,4,5,1 overlap on column 3
# 2,1,0,1,0 and 0,1,3,5,3 overlap on column 3
# 2,1,0,1,0 and 5,3,1,0,2 overlap on column 0
# 2,1,0,1,0 and 3,0,5,1,3 fit all columns
# 2,1,0,1,0 and 5,3,5,2,5 overlap on column 0
# 2,1,0,1,0 and 5,3,4,3,1 overlap on column 0
# 2,1,0,1,0 and 1,0,5,3,1 fit all columns
# 2,1,0,1,0 and 2,5,2,0,1 overlap on column 1
# 2,1,0,1,0 and 0,1,2,3,4 fit all columns
# 2,1,0,1,0 and 0,4,0,3,0 fit all columns
# 2,1,0,1,0 and 3,1,3,1,3 fit all columns
# 2,1,0,1,0 and 1,4,5,2,3 fit all columns
# 2,1,0,1,0 and 3,0,2,5,2 overlap on column 3
# 2,1,0,1,0 and 3,1,0,5,2 overlap on column 3
# 2,1,0,1,0 and 5,2,4,1,5 overlap on column 0
# 2,1,0,1,0 and 1,3,5,2,1 fit all columns
# 2,1,0,1,0 and 1,5,4,5,3 overlap on column 1
# 2,1,0,1,0 and 3,1,4,1,0 fit all columns
# 2,1,0,1,0 and 5,2,1,0,5 overlap on column 0
# 2,1,0,1,0 and 4,2,1,3,0 overlap on column 0
# 2,1,0,1,0 and 4,2,5,3,0 overlap on column 0
# 2,1,0,1,0 and 1,0,3,1,4 fit all columns
# 2,1,0,1,0 and 4,3,1,3,5 overlap on column 0
# 2,1,0,1,0 and 3,5,3,5,0 overlap on column 1
# 2,1,0,1,0 and 0,3,0,2,4 fit all columns
# 2,1,0,1,0 and 1,0,5,3,0 fit all columns
# 2,1,0,1,0 and 3,1,5,2,4 fit all columns
# 2,1,0,1,0 and 1,5,1,0,2 overlap on column 1
# 2,1,0,1,0 and 0,5,1,4,1 overlap on column 1
# 2,1,0,1,0 and 2,5,0,2,4 overlap on column 1
# 2,1,0,1,0 and 3,2,4,2,3 fit all columns
# 2,1,0,1,0 and 1,5,1,2,5 overlap on column 1
# 2,1,0,1,0 and 0,5,4,2,1 overlap on column 1
# 2,1,0,1,0 and 5,3,0,3,1 overlap on column 0
# 2,1,0,1,0 and 5,1,4,2,0 overlap on column 0
# 2,1,0,1,0 and 3,4,3,1,2 fit all columns
# 2,1,0,1,0 and 0,1,5,1,0 fit all columns
# 2,1,0,1,0 and 5,4,5,3,0 overlap on column 0
# 2,1,0,1,0 and 2,1,0,4,0 fit all columns
# 2,1,0,1,0 and 4,5,1,2,1 overlap on column 0
# 2,1,0,1,0 and 2,5,1,5,0 overlap on column 1
# 2,1,0,1,0 and 0,1,2,1,3 fit all columns
# 2,1,0,1,0 and 4,1,5,3,4 overlap on column 0
# 2,1,0,1,0 and 0,5,3,1,4 overlap on column 1
# 2,1,0,1,0 and 4,1,5,0,1 overlap on column 0
# 2,1,0,1,0 and 3,5,2,4,5 overlap on column 1
# 2,1,0,1,0 and 3,5,3,5,4 overlap on column 1
# 2,1,0,1,0 and 1,5,1,0,1 overlap on column 1
# 2,1,0,1,0 and 1,3,0,2,1 fit all columns
# 2,1,0,1,0 and 5,0,3,1,4 overlap on column 0
# 2,1,0,1,0 and 4,1,5,3,2 overlap on column 0
# 2,1,0,1,0 and 4,2,3,4,5 overlap on column 0
# 2,1,0,1,0 and 3,2,0,2,0 fit all columns
# 2,1,0,1,0 and 3,5,1,2,3 overlap on column 1
# 2,1,0,1,0 and 1,2,4,1,3 fit all columns
# 2,1,0,1,0 and 1,5,0,3,4 overlap on column 1
# 2,1,0,1,0 and 3,1,0,3,5 fit all columns
# 2,1,0,1,0 and 5,3,4,2,3 overlap on column 0
# 2,1,0,1,0 and 1,5,2,5,2 overlap on column 1
# 2,1,0,1,0 and 4,5,0,3,4 overlap on column 0
# 2,1,0,1,0 and 4,2,3,4,2 overlap on column 0
# 2,1,0,1,0 and 2,3,1,2,4 fit all columns
# 2,1,0,1,0 and 3,5,1,5,0 overlap on column 1
# 2,1,0,1,0 and 5,2,3,1,3 overlap on column 0
# 2,1,0,1,0 and 0,3,4,1,2 fit all columns
# 2,1,0,1,0 and 4,0,1,3,4 overlap on column 0
# 2,1,0,1,0 and 2,5,1,4,0 overlap on column 1
# 2,1,0,1,0 and 2,1,4,3,2 fit all columns
# 2,1,0,1,0 and 0,1,2,4,1 fit all columns
# 2,1,0,1,0 and 0,1,4,0,3 fit all columns
# 2,1,0,1,0 and 1,5,3,0,4 overlap on column 1
# 2,1,0,1,0 and 2,4,0,2,0 fit all columns
# 2,1,0,1,0 and 3,5,0,4,1 overlap on column 1
# 2,1,0,1,0 and 0,2,3,2,3 fit all columns
# 2,1,0,1,0 and 3,2,1,0,4 fit all columns
# 2,1,0,1,0 and 1,3,4,2,3 fit all columns
# 2,1,0,1,0 and 1,0,4,3,0 fit all columns
# 2,1,0,1,0 and 0,1,4,1,4 fit all columns
# 2,1,0,1,0 and 5,1,0,1,3 overlap on column 0
# 2,1,0,1,0 and 2,4,2,1,3 fit all columns
# 2,1,0,1,0 and 3,4,3,2,4 fit all columns
# 2,1,0,1,0 and 3,1,0,5,1 overlap on column 3
# 2,1,0,1,0 and 0,4,5,0,2 fit all columns
# 2,1,0,1,0 and 4,5,4,5,1 overlap on column 0
# 2,1,0,1,0 and 5,1,4,3,4 overlap on column 0
# 2,1,0,1,0 and 4,1,5,3,0 overlap on column 0
# 2,1,0,1,0 and 4,1,3,5,0 overlap on column 0
# 2,1,0,1,0 and 0,4,1,3,5 fit all columns
# 2,1,0,1,0 and 0,1,5,3,5 fit all columns
# 2,1,0,1,0 and 5,1,0,3,4 overlap on column 0
# 2,1,0,1,0 and 0,5,1,0,5 overlap on column 1
# 2,1,0,1,0 and 5,0,4,0,1 overlap on column 0
# 2,1,0,1,0 and 2,4,0,3,1 fit all columns
# 2,1,0,1,0 and 5,3,5,1,3 overlap on column 0
# 2,1,0,1,0 and 1,0,3,2,5 fit all columns
# 2,1,0,1,0 and 5,1,5,3,1 overlap on column 0
# 2,1,0,1,0 and 0,3,1,2,4 fit all columns
# 2,1,0,1,0 and 2,0,4,0,2 fit all columns
# 2,1,0,1,0 and 5,1,3,1,3 overlap on column 0
# 2,1,0,1,0 and 5,0,4,1,4 overlap on column 0
# 2,1,0,1,0 and 1,4,5,0,4 fit all columns
# 2,1,0,1,0 and 5,2,1,2,0 overlap on column 0
# 2,1,0,1,0 and 1,5,4,3,0 overlap on column 1
# 2,1,0,1,0 and 4,3,5,0,3 overlap on column 0
# 2,1,0,1,0 and 5,4,1,0,5 overlap on column 0
# 2,1,0,1,0 and 3,1,4,0,3 fit all columns
# 2,1,0,1,0 and 3,4,3,4,1 fit all columns
# 2,1,0,1,0 and 1,4,0,4,2 fit all columns
# 2,1,0,1,0 and 1,5,3,2,1 overlap on column 1
# 2,1,0,1,0 and 3,5,1,5,3 overlap on column 1
# 2,1,0,1,0 and 5,4,0,4,0 overlap on column 0
# 2,1,0,1,0 and 3,2,4,2,5 fit all columns
# 2,1,0,1,0 and 2,1,4,1,0 fit all columns
# 2,1,0,1,0 and 2,5,3,5,3 overlap on column 1
# 2,1,0,1,0 and 2,0,2,0,4 fit all columns
# 2,1,0,1,0 and 5,0,4,2,0 overlap on column 0
# 2,1,0,1,0 and 3,0,1,0,1 fit all columns
# 2,1,0,1,0 and 1,0,5,4,2 fit all columns
# 2,1,0,1,0 and 2,0,1,0,3 fit all columns
# 2,1,0,1,0 and 3,5,4,2,1 overlap on column 1
# 2,1,0,1,0 and 5,2,1,5,0 overlap on column 0
# 2,1,0,1,0 and 3,1,2,4,1 fit all columns
# 2,1,0,1,0 and 3,0,4,2,1 fit all columns
# 2,1,0,1,0 and 0,5,2,0,5 overlap on column 1
# 2,1,0,1,0 and 4,5,0,1,5 overlap on column 0
# 2,1,0,1,0 and 0,3,0,3,1 fit all columns
# 2,1,0,1,0 and 1,3,2,3,0 fit all columns
# 2,1,0,1,0 and 3,2,1,2,5 fit all columns
# 2,1,0,1,0 and 0,3,2,0,5 fit all columns
# 2,1,0,1,0 and 0,4,3,5,2 overlap on column 3
# 2,1,0,1,0 and 1,0,5,1,0 fit all columns
# 2,1,0,1,0 and 5,0,3,5,2 overlap on column 0
# 2,1,0,1,0 and 5,0,1,4,2 overlap on column 0
# 2,1,0,1,0 and 0,2,3,1,3 fit all columns
# 2,1,0,1,0 and 4,0,1,4,3 overlap on column 0
# 2,1,0,1,0 and 4,3,5,0,4 overlap on column 0
# 2,1,0,1,0 and 0,5,2,0,3 overlap on column 1
# 2,1,0,1,0 and 0,3,2,5,1 overlap on column 3
# 2,1,0,1,0 and 2,5,1,4,5 overlap on column 1
# 2,1,0,1,0 and 0,1,5,3,0 fit all columns
# 2,1,0,1,0 and 4,3,5,3,0 overlap on column 0
# 2,1,0,1,0 and 0,2,3,0,3 fit all columns
# 2,1,0,1,0 and 5,2,3,1,2 overlap on column 0
# 2,1,0,1,0 and 1,2,5,3,1 fit all columns
# 2,1,0,1,0 and 2,0,1,4,3 fit all columns
# 2,1,0,1,0 and 0,3,0,1,3 fit all columns
# 2,1,0,1,0 and 3,2,1,0,2 fit all columns
# 2,1,0,1,0 and 1,0,3,1,0 fit all columns
# 2,1,0,1,0 and 3,1,3,2,3 fit all columns
# 2,1,0,1,0 and 3,1,3,4,5 fit all columns
# 2,1,0,1,0 and 2,1,4,5,4 overlap on column 3
# 2,1,0,1,0 and 1,2,0,2,5 fit all columns
# 2,1,0,1,0 and 2,1,2,0,4 fit all columns
# 2,1,0,1,0 and 5,2,4,5,4 overlap on column 0
# 2,1,0,1,0 and 3,5,1,4,5 overlap on column 1
# 2,1,0,1,0 and 3,2,0,5,1 overlap on column 3
# 2,1,0,1,0 and 0,3,2,4,3 fit all columns
# 2,1,0,1,0 and 0,5,4,1,0 overlap on column 1
# 2,1,0,1,0 and 5,1,3,2,0 overlap on column 0
# 2,1,0,1,0 and 3,4,1,4,0 fit all columns
# 2,1,0,1,0 and 2,5,1,0,5 overlap on column 1
# 2,1,0,1,0 and 4,2,3,4,1 overlap on column 0
# 2,1,0,1,0 and 1,2,4,3,0 fit all columns
# 2,1,0,1,0 and 1,0,3,0,5 fit all columns
# 2,1,0,1,0 and 1,4,0,5,3 overlap on column 3
# 2,1,0,1,0 and 4,0,2,5,1 overlap on column 0
# 2,1,0,1,0 and 4,5,3,0,2 overlap on column 0
# 2,1,0,1,0 and 1,2,5,1,3 fit all columns
# 2,1,0,1,0 and 1,3,2,3,4 fit all columns
# 2,1,0,1,0 and 0,2,3,5,2 overlap on column 3
# 2,1,0,1,0 and 4,1,3,0,2 overlap on column 0
# 2,1,0,1,0 and 3,5,3,4,2 overlap on column 1
# 2,1,0,1,0 and 2,0,3,0,3 fit all columns
# 2,1,0,1,0 and 3,5,0,3,5 overlap on column 1
# 3,0,4,0,2 and 5,1,2,1,4 overlap on column 0
# 3,0,4,0,2 and 2,5,2,1,3 overlap on column 2
# 3,0,4,0,2 and 0,5,3,5,4 overlap on column 2
# 3,0,4,0,2 and 0,5,1,4,3 fit all columns
# 3,0,4,0,2 and 3,4,5,3,5 overlap on column 0
# 3,0,4,0,2 and 5,3,4,2,0 overlap on column 0
# 3,0,4,0,2 and 0,3,4,2,5 overlap on column 2
# 3,0,4,0,2 and 1,4,0,5,1 fit all columns
# 3,0,4,0,2 and 0,1,0,1,4 overlap on column 4
# 3,0,4,0,2 and 1,0,1,0,5 overlap on column 4
# 3,0,4,0,2 and 3,1,3,4,3 overlap on column 0
# 3,0,4,0,2 and 3,1,0,3,2 overlap on column 0
# 3,0,4,0,2 and 4,5,0,2,3 overlap on column 0
# 3,0,4,0,2 and 0,3,1,0,1 fit all columns
# 3,0,4,0,2 and 5,1,5,0,2 overlap on column 0
# 3,0,4,0,2 and 5,1,5,2,0 overlap on column 0
# 3,0,4,0,2 and 3,4,1,5,4 overlap on column 0
# 3,0,4,0,2 and 5,1,4,5,3 overlap on column 0
# 3,0,4,0,2 and 4,5,4,0,1 overlap on column 0
# 3,0,4,0,2 and 2,3,2,5,4 overlap on column 2
# 3,0,4,0,2 and 1,2,0,4,2 fit all columns
# 3,0,4,0,2 and 5,4,3,5,2 overlap on column 0
# 3,0,4,0,2 and 1,5,0,2,1 fit all columns
# 3,0,4,0,2 and 0,2,0,3,1 fit all columns
# 3,0,4,0,2 and 2,3,1,5,1 fit all columns
# 3,0,4,0,2 and 3,2,5,3,1 overlap on column 0
# 3,0,4,0,2 and 5,0,5,3,2 overlap on column 0
# 3,0,4,0,2 and 0,2,3,4,1 overlap on column 2
# 3,0,4,0,2 and 4,5,4,5,4 overlap on column 0
# 3,0,4,0,2 and 4,3,2,0,3 overlap on column 0
# 3,0,4,0,2 and 3,2,5,0,2 overlap on column 0
# 3,0,4,0,2 and 5,1,2,5,3 overlap on column 0
# 3,0,4,0,2 and 5,4,1,4,0 overlap on column 0
# 3,0,4,0,2 and 1,0,5,3,2 overlap on column 2
# 3,0,4,0,2 and 4,3,5,4,3 overlap on column 0
# 3,0,4,0,2 and 2,5,4,0,3 overlap on column 2
# 3,0,4,0,2 and 0,2,5,0,2 overlap on column 2
# 3,0,4,0,2 and 4,0,5,1,0 overlap on column 0
# 3,0,4,0,2 and 1,2,4,5,3 overlap on column 2
# 3,0,4,0,2 and 3,1,3,5,3 overlap on column 0
# 3,0,4,0,2 and 3,2,4,1,2 overlap on column 0
# 3,0,4,0,2 and 2,4,0,3,0 fit all columns
# 3,0,4,0,2 and 3,5,0,4,0 overlap on column 0
# 3,0,4,0,2 and 3,5,4,5,2 overlap on column 0
# 3,0,4,0,2 and 1,2,5,2,0 overlap on column 2
# 3,0,4,0,2 and 4,0,4,1,2 overlap on column 0
# 3,0,4,0,2 and 3,4,0,3,0 overlap on column 0
# 3,0,4,0,2 and 5,1,5,4,3 overlap on column 0
# 3,0,4,0,2 and 4,5,4,5,2 overlap on column 0
# 3,0,4,0,2 and 4,2,0,3,5 overlap on column 0
# 3,0,4,0,2 and 2,3,4,5,2 overlap on column 2
# 3,0,4,0,2 and 3,4,1,5,2 overlap on column 0
# 3,0,4,0,2 and 0,1,3,2,0 overlap on column 2
# 3,0,4,0,2 and 4,3,5,1,0 overlap on column 0
# 3,0,4,0,2 and 3,0,1,5,3 overlap on column 0
# 3,0,4,0,2 and 3,1,5,3,4 overlap on column 0
# 3,0,4,0,2 and 1,0,4,1,5 overlap on column 2
# 3,0,4,0,2 and 1,0,1,0,4 overlap on column 4
# 3,0,4,0,2 and 3,2,3,1,0 overlap on column 0
# 3,0,4,0,2 and 0,5,3,4,3 overlap on column 2
# 3,0,4,0,2 and 4,1,2,5,0 overlap on column 0
# 3,0,4,0,2 and 4,3,4,2,3 overlap on column 0
# 3,0,4,0,2 and 1,0,1,5,2 fit all columns
# 3,0,4,0,2 and 0,2,4,5,1 overlap on column 2
# 3,0,4,0,2 and 3,4,5,3,0 overlap on column 0
# 3,0,4,0,2 and 0,2,3,1,5 overlap on column 2
# 3,0,4,0,2 and 1,2,0,5,2 fit all columns
# 3,0,4,0,2 and 4,5,4,1,5 overlap on column 0
# 3,0,4,0,2 and 0,3,5,3,5 overlap on column 2
# 3,0,4,0,2 and 4,0,4,5,2 overlap on column 0
# 3,0,4,0,2 and 5,3,5,1,2 overlap on column 0
# 3,0,4,0,2 and 1,3,5,1,5 overlap on column 2
# 3,0,4,0,2 and 0,2,3,2,0 overlap on column 2
# 3,0,4,0,2 and 5,3,2,4,3 overlap on column 0
# 3,0,4,0,2 and 5,1,5,1,3 overlap on column 0
# 3,0,4,0,2 and 3,5,4,1,0 overlap on column 0
# 3,0,4,0,2 and 1,2,4,5,1 overlap on column 2
# 3,0,4,0,2 and 0,1,3,5,3 overlap on column 2
# 3,0,4,0,2 and 5,3,1,0,2 overlap on column 0
# 3,0,4,0,2 and 3,0,5,1,3 overlap on column 0
# 3,0,4,0,2 and 5,3,5,2,5 overlap on column 0
# 3,0,4,0,2 and 5,3,4,3,1 overlap on column 0
# 3,0,4,0,2 and 1,0,5,3,1 overlap on column 2
# 3,0,4,0,2 and 2,5,2,0,1 overlap on column 2
# 3,0,4,0,2 and 0,1,2,3,4 overlap on column 2
# 3,0,4,0,2 and 0,4,0,3,0 fit all columns
# 3,0,4,0,2 and 3,1,3,1,3 overlap on column 0
# 3,0,4,0,2 and 1,4,5,2,3 overlap on column 2
# 3,0,4,0,2 and 3,0,2,5,2 overlap on column 0
# 3,0,4,0,2 and 3,1,0,5,2 overlap on column 0
# 3,0,4,0,2 and 5,2,4,1,5 overlap on column 0
# 3,0,4,0,2 and 1,3,5,2,1 overlap on column 2
# 3,0,4,0,2 and 1,5,4,5,3 overlap on column 2
# 3,0,4,0,2 and 3,1,4,1,0 overlap on column 0
# 3,0,4,0,2 and 5,2,1,0,5 overlap on column 0
# 3,0,4,0,2 and 4,2,1,3,0 overlap on column 0
# 3,0,4,0,2 and 4,2,5,3,0 overlap on column 0
# 3,0,4,0,2 and 1,0,3,1,4 overlap on column 2
# 3,0,4,0,2 and 4,3,1,3,5 overlap on column 0
# 3,0,4,0,2 and 3,5,3,5,0 overlap on column 0
# 3,0,4,0,2 and 0,3,0,2,4 overlap on column 4
# 3,0,4,0,2 and 1,0,5,3,0 overlap on column 2
# 3,0,4,0,2 and 3,1,5,2,4 overlap on column 0
# 3,0,4,0,2 and 1,5,1,0,2 fit all columns
# 3,0,4,0,2 and 0,5,1,4,1 fit all columns
# 3,0,4,0,2 and 2,5,0,2,4 overlap on column 4
# 3,0,4,0,2 and 3,2,4,2,3 overlap on column 0
# 3,0,4,0,2 and 1,5,1,2,5 overlap on column 4
# 3,0,4,0,2 and 0,5,4,2,1 overlap on column 2
# 3,0,4,0,2 and 5,3,0,3,1 overlap on column 0
# 3,0,4,0,2 and 5,1,4,2,0 overlap on column 0
# 3,0,4,0,2 and 3,4,3,1,2 overlap on column 0
# 3,0,4,0,2 and 0,1,5,1,0 overlap on column 2
# 3,0,4,0,2 and 5,4,5,3,0 overlap on column 0
# 3,0,4,0,2 and 2,1,0,4,0 fit all columns
# 3,0,4,0,2 and 4,5,1,2,1 overlap on column 0
# 3,0,4,0,2 and 2,5,1,5,0 fit all columns
# 3,0,4,0,2 and 0,1,2,1,3 overlap on column 2
# 3,0,4,0,2 and 4,1,5,3,4 overlap on column 0
# 3,0,4,0,2 and 0,5,3,1,4 overlap on column 2
# 3,0,4,0,2 and 4,1,5,0,1 overlap on column 0
# 3,0,4,0,2 and 3,5,2,4,5 overlap on column 0
# 3,0,4,0,2 and 3,5,3,5,4 overlap on column 0
# 3,0,4,0,2 and 1,5,1,0,1 fit all columns
# 3,0,4,0,2 and 1,3,0,2,1 fit all columns
# 3,0,4,0,2 and 5,0,3,1,4 overlap on column 0
# 3,0,4,0,2 and 4,1,5,3,2 overlap on column 0
# 3,0,4,0,2 and 4,2,3,4,5 overlap on column 0
# 3,0,4,0,2 and 3,2,0,2,0 overlap on column 0
# 3,0,4,0,2 and 3,5,1,2,3 overlap on column 0
# 3,0,4,0,2 and 1,2,4,1,3 overlap on column 2
# 3,0,4,0,2 and 1,5,0,3,4 overlap on column 4
# 3,0,4,0,2 and 3,1,0,3,5 overlap on column 0
# 3,0,4,0,2 and 5,3,4,2,3 overlap on column 0
# 3,0,4,0,2 and 1,5,2,5,2 overlap on column 2
# 3,0,4,0,2 and 4,5,0,3,4 overlap on column 0
# 3,0,4,0,2 and 4,2,3,4,2 overlap on column 0
# 3,0,4,0,2 and 2,3,1,2,4 overlap on column 4
# 3,0,4,0,2 and 3,5,1,5,0 overlap on column 0
# 3,0,4,0,2 and 5,2,3,1,3 overlap on column 0
# 3,0,4,0,2 and 0,3,4,1,2 overlap on column 2
# 3,0,4,0,2 and 4,0,1,3,4 overlap on column 0
# 3,0,4,0,2 and 2,5,1,4,0 fit all columns
# 3,0,4,0,2 and 2,1,4,3,2 overlap on column 2
# 3,0,4,0,2 and 0,1,2,4,1 overlap on column 2
# 3,0,4,0,2 and 0,1,4,0,3 overlap on column 2
# 3,0,4,0,2 and 1,5,3,0,4 overlap on column 2
# 3,0,4,0,2 and 2,4,0,2,0 fit all columns
# 3,0,4,0,2 and 3,5,0,4,1 overlap on column 0
# 3,0,4,0,2 and 0,2,3,2,3 overlap on column 2
# 3,0,4,0,2 and 3,2,1,0,4 overlap on column 0
# 3,0,4,0,2 and 1,3,4,2,3 overlap on column 2
# 3,0,4,0,2 and 1,0,4,3,0 overlap on column 2
# 3,0,4,0,2 and 0,1,4,1,4 overlap on column 2
# 3,0,4,0,2 and 5,1,0,1,3 overlap on column 0
# 3,0,4,0,2 and 2,4,2,1,3 overlap on column 2
# 3,0,4,0,2 and 3,4,3,2,4 overlap on column 0
# 3,0,4,0,2 and 3,1,0,5,1 overlap on column 0
# 3,0,4,0,2 and 0,4,5,0,2 overlap on column 2
# 3,0,4,0,2 and 4,5,4,5,1 overlap on column 0
# 3,0,4,0,2 and 5,1,4,3,4 overlap on column 0
# 3,0,4,0,2 and 4,1,5,3,0 overlap on column 0
# 3,0,4,0,2 and 4,1,3,5,0 overlap on column 0
# 3,0,4,0,2 and 0,4,1,3,5 overlap on column 4
# 3,0,4,0,2 and 0,1,5,3,5 overlap on column 2
# 3,0,4,0,2 and 5,1,0,3,4 overlap on column 0
# 3,0,4,0,2 and 0,5,1,0,5 overlap on column 4
# 3,0,4,0,2 and 5,0,4,0,1 overlap on column 0
# 3,0,4,0,2 and 2,4,0,3,1 fit all columns
# 3,0,4,0,2 and 5,3,5,1,3 overlap on column 0
# 3,0,4,0,2 and 1,0,3,2,5 overlap on column 2
# 3,0,4,0,2 and 5,1,5,3,1 overlap on column 0
# 3,0,4,0,2 and 0,3,1,2,4 overlap on column 4
# 3,0,4,0,2 and 2,0,4,0,2 overlap on column 2
# 3,0,4,0,2 and 5,1,3,1,3 overlap on column 0
# 3,0,4,0,2 and 5,0,4,1,4 overlap on column 0
# 3,0,4,0,2 and 1,4,5,0,4 overlap on column 2
# 3,0,4,0,2 and 5,2,1,2,0 overlap on column 0
# 3,0,4,0,2 and 1,5,4,3,0 overlap on column 2
# 3,0,4,0,2 and 4,3,5,0,3 overlap on column 0
# 3,0,4,0,2 and 5,4,1,0,5 overlap on column 0
# 3,0,4,0,2 and 3,1,4,0,3 overlap on column 0
# 3,0,4,0,2 and 3,4,3,4,1 overlap on column 0
# 3,0,4,0,2 and 1,4,0,4,2 fit all columns
# 3,0,4,0,2 and 1,5,3,2,1 overlap on column 2
# 3,0,4,0,2 and 3,5,1,5,3 overlap on column 0
# 3,0,4,0,2 and 5,4,0,4,0 overlap on column 0
# 3,0,4,0,2 and 3,2,4,2,5 overlap on column 0
# 3,0,4,0,2 and 2,1,4,1,0 overlap on column 2
# 3,0,4,0,2 and 2,5,3,5,3 overlap on column 2
# 3,0,4,0,2 and 2,0,2,0,4 overlap on column 2
# 3,0,4,0,2 and 5,0,4,2,0 overlap on column 0
# 3,0,4,0,2 and 3,0,1,0,1 overlap on column 0
# 3,0,4,0,2 and 1,0,5,4,2 overlap on column 2
# 3,0,4,0,2 and 2,0,1,0,3 fit all columns
# 3,0,4,0,2 and 3,5,4,2,1 overlap on column 0
# 3,0,4,0,2 and 5,2,1,5,0 overlap on column 0
# 3,0,4,0,2 and 3,1,2,4,1 overlap on column 0
# 3,0,4,0,2 and 3,0,4,2,1 overlap on column 0
# 3,0,4,0,2 and 0,5,2,0,5 overlap on column 2
# 3,0,4,0,2 and 4,5,0,1,5 overlap on column 0
# 3,0,4,0,2 and 0,3,0,3,1 fit all columns
# 3,0,4,0,2 and 1,3,2,3,0 overlap on column 2
# 3,0,4,0,2 and 3,2,1,2,5 overlap on column 0
# 3,0,4,0,2 and 0,3,2,0,5 overlap on column 2
# 3,0,4,0,2 and 0,4,3,5,2 overlap on column 2
# 3,0,4,0,2 and 1,0,5,1,0 overlap on column 2
# 3,0,4,0,2 and 5,0,3,5,2 overlap on column 0
# 3,0,4,0,2 and 5,0,1,4,2 overlap on column 0
# 3,0,4,0,2 and 0,2,3,1,3 overlap on column 2
# 3,0,4,0,2 and 4,0,1,4,3 overlap on column 0
# 3,0,4,0,2 and 4,3,5,0,4 overlap on column 0
# 3,0,4,0,2 and 0,5,2,0,3 overlap on column 2
# 3,0,4,0,2 and 0,3,2,5,1 overlap on column 2
# 3,0,4,0,2 and 2,5,1,4,5 overlap on column 4
# 3,0,4,0,2 and 0,1,5,3,0 overlap on column 2
# 3,0,4,0,2 and 4,3,5,3,0 overlap on column 0
# 3,0,4,0,2 and 0,2,3,0,3 overlap on column 2
# 3,0,4,0,2 and 5,2,3,1,2 overlap on column 0
# 3,0,4,0,2 and 1,2,5,3,1 overlap on column 2
# 3,0,4,0,2 and 2,0,1,4,3 fit all columns
# 3,0,4,0,2 and 0,3,0,1,3 fit all columns
# 3,0,4,0,2 and 3,2,1,0,2 overlap on column 0
# 3,0,4,0,2 and 1,0,3,1,0 overlap on column 2
# 3,0,4,0,2 and 3,1,3,2,3 overlap on column 0
# 3,0,4,0,2 and 3,1,3,4,5 overlap on column 0
# 3,0,4,0,2 and 2,1,4,5,4 overlap on column 2
# 3,0,4,0,2 and 1,2,0,2,5 overlap on column 4
# 3,0,4,0,2 and 2,1,2,0,4 overlap on column 2
# 3,0,4,0,2 and 5,2,4,5,4 overlap on column 0
# 3,0,4,0,2 and 3,5,1,4,5 overlap on column 0
# 3,0,4,0,2 and 3,2,0,5,1 overlap on column 0
# 3,0,4,0,2 and 0,3,2,4,3 overlap on column 2
# 3,0,4,0,2 and 0,5,4,1,0 overlap on column 2
# 3,0,4,0,2 and 5,1,3,2,0 overlap on column 0
# 3,0,4,0,2 and 3,4,1,4,0 overlap on column 0
# 3,0,4,0,2 and 2,5,1,0,5 overlap on column 4
# 3,0,4,0,2 and 4,2,3,4,1 overlap on column 0
# 3,0,4,0,2 and 1,2,4,3,0 overlap on column 2
# 3,0,4,0,2 and 1,0,3,0,5 overlap on column 2
# 3,0,4,0,2 and 1,4,0,5,3 fit all columns
# 3,0,4,0,2 and 4,0,2,5,1 overlap on column 0
# 3,0,4,0,2 and 4,5,3,0,2 overlap on column 0
# 3,0,4,0,2 and 1,2,5,1,3 overlap on column 2
# 3,0,4,0,2 and 1,3,2,3,4 overlap on column 2
# 3,0,4,0,2 and 0,2,3,5,2 overlap on column 2
# 3,0,4,0,2 and 4,1,3,0,2 overlap on column 0
# 3,0,4,0,2 and 3,5,3,4,2 overlap on column 0
# 3,0,4,0,2 and 2,0,3,0,3 overlap on column 2
# 3,0,4,0,2 and 3,5,0,3,5 overlap on column 0
# 1,5,0,4,2 and 5,1,2,1,4 overlap on column 0
# 1,5,0,4,2 and 2,5,2,1,3 overlap on column 1
# 1,5,0,4,2 and 0,5,3,5,4 overlap on column 1
# 1,5,0,4,2 and 0,5,1,4,3 overlap on column 1
# 1,5,0,4,2 and 3,4,5,3,5 overlap on column 1
# 1,5,0,4,2 and 5,3,4,2,0 overlap on column 0
# 1,5,0,4,2 and 0,3,4,2,5 overlap on column 1
# 1,5,0,4,2 and 1,4,0,5,1 overlap on column 1
# 1,5,0,4,2 and 0,1,0,1,4 overlap on column 1
# 1,5,0,4,2 and 1,0,1,0,5 overlap on column 4
# 1,5,0,4,2 and 3,1,3,4,3 overlap on column 1
# 1,5,0,4,2 and 3,1,0,3,2 overlap on column 1
# 1,5,0,4,2 and 4,5,0,2,3 overlap on column 1
# 1,5,0,4,2 and 0,3,1,0,1 overlap on column 1
# 1,5,0,4,2 and 5,1,5,0,2 overlap on column 0
# 1,5,0,4,2 and 5,1,5,2,0 overlap on column 0
# 1,5,0,4,2 and 3,4,1,5,4 overlap on column 1
# 1,5,0,4,2 and 5,1,4,5,3 overlap on column 0
# 1,5,0,4,2 and 4,5,4,0,1 overlap on column 1
# 1,5,0,4,2 and 2,3,2,5,4 overlap on column 1
# 1,5,0,4,2 and 1,2,0,4,2 overlap on column 1
# 1,5,0,4,2 and 5,4,3,5,2 overlap on column 0
# 1,5,0,4,2 and 1,5,0,2,1 overlap on column 1
# 1,5,0,4,2 and 0,2,0,3,1 overlap on column 1
# 1,5,0,4,2 and 2,3,1,5,1 overlap on column 1
# 1,5,0,4,2 and 3,2,5,3,1 overlap on column 1
# 1,5,0,4,2 and 5,0,5,3,2 overlap on column 0
# 1,5,0,4,2 and 0,2,3,4,1 overlap on column 1
# 1,5,0,4,2 and 4,5,4,5,4 overlap on column 1
# 1,5,0,4,2 and 4,3,2,0,3 overlap on column 1
# 1,5,0,4,2 and 3,2,5,0,2 overlap on column 1
# 1,5,0,4,2 and 5,1,2,5,3 overlap on column 0
# 1,5,0,4,2 and 5,4,1,4,0 overlap on column 0
# 1,5,0,4,2 and 1,0,5,3,2 overlap on column 3
# 1,5,0,4,2 and 4,3,5,4,3 overlap on column 1
# 1,5,0,4,2 and 2,5,4,0,3 overlap on column 1
# 1,5,0,4,2 and 0,2,5,0,2 overlap on column 1
# 1,5,0,4,2 and 4,0,5,1,0 fit all columns
# 1,5,0,4,2 and 1,2,4,5,3 overlap on column 1
# 1,5,0,4,2 and 3,1,3,5,3 overlap on column 1
# 1,5,0,4,2 and 3,2,4,1,2 overlap on column 1
# 1,5,0,4,2 and 2,4,0,3,0 overlap on column 1
# 1,5,0,4,2 and 3,5,0,4,0 overlap on column 1
# 1,5,0,4,2 and 3,5,4,5,2 overlap on column 1
# 1,5,0,4,2 and 1,2,5,2,0 overlap on column 1
# 1,5,0,4,2 and 4,0,4,1,2 fit all columns
# 1,5,0,4,2 and 3,4,0,3,0 overlap on column 1
# 1,5,0,4,2 and 5,1,5,4,3 overlap on column 0
# 1,5,0,4,2 and 4,5,4,5,2 overlap on column 1
# 1,5,0,4,2 and 4,2,0,3,5 overlap on column 1
# 1,5,0,4,2 and 2,3,4,5,2 overlap on column 1
# 1,5,0,4,2 and 3,4,1,5,2 overlap on column 1
# 1,5,0,4,2 and 0,1,3,2,0 overlap on column 1
# 1,5,0,4,2 and 4,3,5,1,0 overlap on column 1
# 1,5,0,4,2 and 3,0,1,5,3 overlap on column 3
# 1,5,0,4,2 and 3,1,5,3,4 overlap on column 1
# 1,5,0,4,2 and 1,0,4,1,5 overlap on column 4
# 1,5,0,4,2 and 1,0,1,0,4 overlap on column 4
# 1,5,0,4,2 and 3,2,3,1,0 overlap on column 1
# 1,5,0,4,2 and 0,5,3,4,3 overlap on column 1
# 1,5,0,4,2 and 4,1,2,5,0 overlap on column 1
# 1,5,0,4,2 and 4,3,4,2,3 overlap on column 1
# 1,5,0,4,2 and 1,0,1,5,2 overlap on column 3
# 1,5,0,4,2 and 0,2,4,5,1 overlap on column 1
# 1,5,0,4,2 and 3,4,5,3,0 overlap on column 1
# 1,5,0,4,2 and 0,2,3,1,5 overlap on column 1
# 1,5,0,4,2 and 1,2,0,5,2 overlap on column 1
# 1,5,0,4,2 and 4,5,4,1,5 overlap on column 1
# 1,5,0,4,2 and 0,3,5,3,5 overlap on column 1
# 1,5,0,4,2 and 4,0,4,5,2 overlap on column 3
# 1,5,0,4,2 and 5,3,5,1,2 overlap on column 0
# 1,5,0,4,2 and 1,3,5,1,5 overlap on column 1
# 1,5,0,4,2 and 0,2,3,2,0 overlap on column 1
# 1,5,0,4,2 and 5,3,2,4,3 overlap on column 0
# 1,5,0,4,2 and 5,1,5,1,3 overlap on column 0
# 1,5,0,4,2 and 3,5,4,1,0 overlap on column 1
# 1,5,0,4,2 and 1,2,4,5,1 overlap on column 1
# 1,5,0,4,2 and 0,1,3,5,3 overlap on column 1
# 1,5,0,4,2 and 5,3,1,0,2 overlap on column 0
# 1,5,0,4,2 and 3,0,5,1,3 fit all columns
# 1,5,0,4,2 and 5,3,5,2,5 overlap on column 0
# 1,5,0,4,2 and 5,3,4,3,1 overlap on column 0
# 1,5,0,4,2 and 1,0,5,3,1 overlap on column 3
# 1,5,0,4,2 and 2,5,2,0,1 overlap on column 1
# 1,5,0,4,2 and 0,1,2,3,4 overlap on column 1
# 1,5,0,4,2 and 0,4,0,3,0 overlap on column 1
# 1,5,0,4,2 and 3,1,3,1,3 overlap on column 1
# 1,5,0,4,2 and 1,4,5,2,3 overlap on column 1
# 1,5,0,4,2 and 3,0,2,5,2 overlap on column 3
# 1,5,0,4,2 and 3,1,0,5,2 overlap on column 1
# 1,5,0,4,2 and 5,2,4,1,5 overlap on column 0
# 1,5,0,4,2 and 1,3,5,2,1 overlap on column 1
# 1,5,0,4,2 and 1,5,4,5,3 overlap on column 1
# 1,5,0,4,2 and 3,1,4,1,0 overlap on column 1
# 1,5,0,4,2 and 5,2,1,0,5 overlap on column 0
# 1,5,0,4,2 and 4,2,1,3,0 overlap on column 1
# 1,5,0,4,2 and 4,2,5,3,0 overlap on column 1
# 1,5,0,4,2 and 1,0,3,1,4 overlap on column 4
# 1,5,0,4,2 and 4,3,1,3,5 overlap on column 1
# 1,5,0,4,2 and 3,5,3,5,0 overlap on column 1
# 1,5,0,4,2 and 0,3,0,2,4 overlap on column 1
# 1,5,0,4,2 and 1,0,5,3,0 overlap on column 3
# 1,5,0,4,2 and 3,1,5,2,4 overlap on column 1
# 1,5,0,4,2 and 1,5,1,0,2 overlap on column 1
# 1,5,0,4,2 and 0,5,1,4,1 overlap on column 1
# 1,5,0,4,2 and 2,5,0,2,4 overlap on column 1
# 1,5,0,4,2 and 3,2,4,2,3 overlap on column 1
# 1,5,0,4,2 and 1,5,1,2,5 overlap on column 1
# 1,5,0,4,2 and 0,5,4,2,1 overlap on column 1
# 1,5,0,4,2 and 5,3,0,3,1 overlap on column 0
# 1,5,0,4,2 and 5,1,4,2,0 overlap on column 0
# 1,5,0,4,2 and 3,4,3,1,2 overlap on column 1
# 1,5,0,4,2 and 0,1,5,1,0 overlap on column 1
# 1,5,0,4,2 and 5,4,5,3,0 overlap on column 0
# 1,5,0,4,2 and 2,1,0,4,0 overlap on column 1
# 1,5,0,4,2 and 4,5,1,2,1 overlap on column 1
# 1,5,0,4,2 and 2,5,1,5,0 overlap on column 1
# 1,5,0,4,2 and 0,1,2,1,3 overlap on column 1
# 1,5,0,4,2 and 4,1,5,3,4 overlap on column 1
# 1,5,0,4,2 and 0,5,3,1,4 overlap on column 1
# 1,5,0,4,2 and 4,1,5,0,1 overlap on column 1
# 1,5,0,4,2 and 3,5,2,4,5 overlap on column 1
# 1,5,0,4,2 and 3,5,3,5,4 overlap on column 1
# 1,5,0,4,2 and 1,5,1,0,1 overlap on column 1
# 1,5,0,4,2 and 1,3,0,2,1 overlap on column 1
# 1,5,0,4,2 and 5,0,3,1,4 overlap on column 0
# 1,5,0,4,2 and 4,1,5,3,2 overlap on column 1
# 1,5,0,4,2 and 4,2,3,4,5 overlap on column 1
# 1,5,0,4,2 and 3,2,0,2,0 overlap on column 1
# 1,5,0,4,2 and 3,5,1,2,3 overlap on column 1
# 1,5,0,4,2 and 1,2,4,1,3 overlap on column 1
# 1,5,0,4,2 and 1,5,0,3,4 overlap on column 1
# 1,5,0,4,2 and 3,1,0,3,5 overlap on column 1
# 1,5,0,4,2 and 5,3,4,2,3 overlap on column 0
# 1,5,0,4,2 and 1,5,2,5,2 overlap on column 1
# 1,5,0,4,2 and 4,5,0,3,4 overlap on column 1
# 1,5,0,4,2 and 4,2,3,4,2 overlap on column 1
# 1,5,0,4,2 and 2,3,1,2,4 overlap on column 1
# 1,5,0,4,2 and 3,5,1,5,0 overlap on column 1
# 1,5,0,4,2 and 5,2,3,1,3 overlap on column 0
# 1,5,0,4,2 and 0,3,4,1,2 overlap on column 1
# 1,5,0,4,2 and 4,0,1,3,4 overlap on column 3
# 1,5,0,4,2 and 2,5,1,4,0 overlap on column 1
# 1,5,0,4,2 and 2,1,4,3,2 overlap on column 1
# 1,5,0,4,2 and 0,1,2,4,1 overlap on column 1
# 1,5,0,4,2 and 0,1,4,0,3 overlap on column 1
# 1,5,0,4,2 and 1,5,3,0,4 overlap on column 1
# 1,5,0,4,2 and 2,4,0,2,0 overlap on column 1
# 1,5,0,4,2 and 3,5,0,4,1 overlap on column 1
# 1,5,0,4,2 and 0,2,3,2,3 overlap on column 1
# 1,5,0,4,2 and 3,2,1,0,4 overlap on column 1
# 1,5,0,4,2 and 1,3,4,2,3 overlap on column 1
# 1,5,0,4,2 and 1,0,4,3,0 overlap on column 3
# 1,5,0,4,2 and 0,1,4,1,4 overlap on column 1
# 1,5,0,4,2 and 5,1,0,1,3 overlap on column 0
# 1,5,0,4,2 and 2,4,2,1,3 overlap on column 1
# 1,5,0,4,2 and 3,4,3,2,4 overlap on column 1
# 1,5,0,4,2 and 3,1,0,5,1 overlap on column 1
# 1,5,0,4,2 and 0,4,5,0,2 overlap on column 1
# 1,5,0,4,2 and 4,5,4,5,1 overlap on column 1
# 1,5,0,4,2 and 5,1,4,3,4 overlap on column 0
# 1,5,0,4,2 and 4,1,5,3,0 overlap on column 1
# 1,5,0,4,2 and 4,1,3,5,0 overlap on column 1
# 1,5,0,4,2 and 0,4,1,3,5 overlap on column 1
# 1,5,0,4,2 and 0,1,5,3,5 overlap on column 1
# 1,5,0,4,2 and 5,1,0,3,4 overlap on column 0
# 1,5,0,4,2 and 0,5,1,0,5 overlap on column 1
# 1,5,0,4,2 and 5,0,4,0,1 overlap on column 0
# 1,5,0,4,2 and 2,4,0,3,1 overlap on column 1
# 1,5,0,4,2 and 5,3,5,1,3 overlap on column 0
# 1,5,0,4,2 and 1,0,3,2,5 overlap on column 3
# 1,5,0,4,2 and 5,1,5,3,1 overlap on column 0
# 1,5,0,4,2 and 0,3,1,2,4 overlap on column 1
# 1,5,0,4,2 and 2,0,4,0,2 fit all columns
# 1,5,0,4,2 and 5,1,3,1,3 overlap on column 0
# 1,5,0,4,2 and 5,0,4,1,4 overlap on column 0
# 1,5,0,4,2 and 1,4,5,0,4 overlap on column 1
# 1,5,0,4,2 and 5,2,1,2,0 overlap on column 0
# 1,5,0,4,2 and 1,5,4,3,0 overlap on column 1
# 1,5,0,4,2 and 4,3,5,0,3 overlap on column 1
# 1,5,0,4,2 and 5,4,1,0,5 overlap on column 0
# 1,5,0,4,2 and 3,1,4,0,3 overlap on column 1
# 1,5,0,4,2 and 3,4,3,4,1 overlap on column 1
# 1,5,0,4,2 and 1,4,0,4,2 overlap on column 1
# 1,5,0,4,2 and 1,5,3,2,1 overlap on column 1
# 1,5,0,4,2 and 3,5,1,5,3 overlap on column 1
# 1,5,0,4,2 and 5,4,0,4,0 overlap on column 0
# 1,5,0,4,2 and 3,2,4,2,5 overlap on column 1
# 1,5,0,4,2 and 2,1,4,1,0 overlap on column 1
# 1,5,0,4,2 and 2,5,3,5,3 overlap on column 1
# 1,5,0,4,2 and 2,0,2,0,4 overlap on column 4
# 1,5,0,4,2 and 5,0,4,2,0 overlap on column 0
# 1,5,0,4,2 and 3,0,1,0,1 fit all columns
# 1,5,0,4,2 and 1,0,5,4,2 overlap on column 3
# 1,5,0,4,2 and 2,0,1,0,3 fit all columns
# 1,5,0,4,2 and 3,5,4,2,1 overlap on column 1
# 1,5,0,4,2 and 5,2,1,5,0 overlap on column 0
# 1,5,0,4,2 and 3,1,2,4,1 overlap on column 1
# 1,5,0,4,2 and 3,0,4,2,1 overlap on column 3
# 1,5,0,4,2 and 0,5,2,0,5 overlap on column 1
# 1,5,0,4,2 and 4,5,0,1,5 overlap on column 1
# 1,5,0,4,2 and 0,3,0,3,1 overlap on column 1
# 1,5,0,4,2 and 1,3,2,3,0 overlap on column 1
# 1,5,0,4,2 and 3,2,1,2,5 overlap on column 1
# 1,5,0,4,2 and 0,3,2,0,5 overlap on column 1
# 1,5,0,4,2 and 0,4,3,5,2 overlap on column 1
# 1,5,0,4,2 and 1,0,5,1,0 fit all columns
# 1,5,0,4,2 and 5,0,3,5,2 overlap on column 0
# 1,5,0,4,2 and 5,0,1,4,2 overlap on column 0
# 1,5,0,4,2 and 0,2,3,1,3 overlap on column 1
# 1,5,0,4,2 and 4,0,1,4,3 overlap on column 3
# 1,5,0,4,2 and 4,3,5,0,4 overlap on column 1
# 1,5,0,4,2 and 0,5,2,0,3 overlap on column 1
# 1,5,0,4,2 and 0,3,2,5,1 overlap on column 1
# 1,5,0,4,2 and 2,5,1,4,5 overlap on column 1
# 1,5,0,4,2 and 0,1,5,3,0 overlap on column 1
# 1,5,0,4,2 and 4,3,5,3,0 overlap on column 1
# 1,5,0,4,2 and 0,2,3,0,3 overlap on column 1
# 1,5,0,4,2 and 5,2,3,1,2 overlap on column 0
# 1,5,0,4,2 and 1,2,5,3,1 overlap on column 1
# 1,5,0,4,2 and 2,0,1,4,3 overlap on column 3
# 1,5,0,4,2 and 0,3,0,1,3 overlap on column 1
# 1,5,0,4,2 and 3,2,1,0,2 overlap on column 1
# 1,5,0,4,2 and 1,0,3,1,0 fit all columns
# 1,5,0,4,2 and 3,1,3,2,3 overlap on column 1
# 1,5,0,4,2 and 3,1,3,4,5 overlap on column 1
# 1,5,0,4,2 and 2,1,4,5,4 overlap on column 1
# 1,5,0,4,2 and 1,2,0,2,5 overlap on column 1
# 1,5,0,4,2 and 2,1,2,0,4 overlap on column 1
# 1,5,0,4,2 and 5,2,4,5,4 overlap on column 0
# 1,5,0,4,2 and 3,5,1,4,5 overlap on column 1
# 1,5,0,4,2 and 3,2,0,5,1 overlap on column 1
# 1,5,0,4,2 and 0,3,2,4,3 overlap on column 1
# 1,5,0,4,2 and 0,5,4,1,0 overlap on column 1
# 1,5,0,4,2 and 5,1,3,2,0 overlap on column 0
# 1,5,0,4,2 and 3,4,1,4,0 overlap on column 1
# 1,5,0,4,2 and 2,5,1,0,5 overlap on column 1
# 1,5,0,4,2 and 4,2,3,4,1 overlap on column 1
# 1,5,0,4,2 and 1,2,4,3,0 overlap on column 1
# 1,5,0,4,2 and 1,0,3,0,5 overlap on column 4
# 1,5,0,4,2 and 1,4,0,5,3 overlap on column 1
# 1,5,0,4,2 and 4,0,2,5,1 overlap on column 3
# 1,5,0,4,2 and 4,5,3,0,2 overlap on column 1
# 1,5,0,4,2 and 1,2,5,1,3 overlap on column 1
# 1,5,0,4,2 and 1,3,2,3,4 overlap on column 1
# 1,5,0,4,2 and 0,2,3,5,2 overlap on column 1
# 1,5,0,4,2 and 4,1,3,0,2 overlap on column 1
# 1,5,0,4,2 and 3,5,3,4,2 overlap on column 1
# 1,5,0,4,2 and 2,0,3,0,3 fit all columns
# 1,5,0,4,2 and 3,5,0,3,5 overlap on column 1
# 5,1,0,5,4 and 5,1,2,1,4 overlap on column 0
# 5,1,0,5,4 and 2,5,2,1,3 overlap on column 0
# 5,1,0,5,4 and 0,5,3,5,4 overlap on column 1
# 5,1,0,5,4 and 0,5,1,4,3 overlap on column 1
# 5,1,0,5,4 and 3,4,5,3,5 overlap on column 0
# 5,1,0,5,4 and 5,3,4,2,0 overlap on column 0
# 5,1,0,5,4 and 0,3,4,2,5 overlap on column 3
# 5,1,0,5,4 and 1,4,0,5,1 overlap on column 0
# 5,1,0,5,4 and 0,1,0,1,4 overlap on column 3
# 5,1,0,5,4 and 1,0,1,0,5 overlap on column 0
# 5,1,0,5,4 and 3,1,3,4,3 overlap on column 0
# 5,1,0,5,4 and 3,1,0,3,2 overlap on column 0
# 5,1,0,5,4 and 4,5,0,2,3 overlap on column 0
# 5,1,0,5,4 and 0,3,1,0,1 fit all columns
# 5,1,0,5,4 and 5,1,5,0,2 overlap on column 0
# 5,1,0,5,4 and 5,1,5,2,0 overlap on column 0
# 5,1,0,5,4 and 3,4,1,5,4 overlap on column 0
# 5,1,0,5,4 and 5,1,4,5,3 overlap on column 0
# 5,1,0,5,4 and 4,5,4,0,1 overlap on column 0
# 5,1,0,5,4 and 2,3,2,5,4 overlap on column 0
# 5,1,0,5,4 and 1,2,0,4,2 overlap on column 0
# 5,1,0,5,4 and 5,4,3,5,2 overlap on column 0
# 5,1,0,5,4 and 1,5,0,2,1 overlap on column 0
# 5,1,0,5,4 and 0,2,0,3,1 overlap on column 3
# 5,1,0,5,4 and 2,3,1,5,1 overlap on column 0
# 5,1,0,5,4 and 3,2,5,3,1 overlap on column 0
# 5,1,0,5,4 and 5,0,5,3,2 overlap on column 0
# 5,1,0,5,4 and 0,2,3,4,1 overlap on column 3
# 5,1,0,5,4 and 4,5,4,5,4 overlap on column 0
# 5,1,0,5,4 and 4,3,2,0,3 overlap on column 0
# 5,1,0,5,4 and 3,2,5,0,2 overlap on column 0
# 5,1,0,5,4 and 5,1,2,5,3 overlap on column 0
# 5,1,0,5,4 and 5,4,1,4,0 overlap on column 0
# 5,1,0,5,4 and 1,0,5,3,2 overlap on column 0
# 5,1,0,5,4 and 4,3,5,4,3 overlap on column 0
# 5,1,0,5,4 and 2,5,4,0,3 overlap on column 0
# 5,1,0,5,4 and 0,2,5,0,2 overlap on column 4
# 5,1,0,5,4 and 4,0,5,1,0 overlap on column 0
# 5,1,0,5,4 and 1,2,4,5,3 overlap on column 0
# 5,1,0,5,4 and 3,1,3,5,3 overlap on column 0
# 5,1,0,5,4 and 3,2,4,1,2 overlap on column 0
# 5,1,0,5,4 and 2,4,0,3,0 overlap on column 0
# 5,1,0,5,4 and 3,5,0,4,0 overlap on column 0
# 5,1,0,5,4 and 3,5,4,5,2 overlap on column 0
# 5,1,0,5,4 and 1,2,5,2,0 overlap on column 0
# 5,1,0,5,4 and 4,0,4,1,2 overlap on column 0
# 5,1,0,5,4 and 3,4,0,3,0 overlap on column 0
# 5,1,0,5,4 and 5,1,5,4,3 overlap on column 0
# 5,1,0,5,4 and 4,5,4,5,2 overlap on column 0
# 5,1,0,5,4 and 4,2,0,3,5 overlap on column 0
# 5,1,0,5,4 and 2,3,4,5,2 overlap on column 0
# 5,1,0,5,4 and 3,4,1,5,2 overlap on column 0
# 5,1,0,5,4 and 0,1,3,2,0 overlap on column 3
# 5,1,0,5,4 and 4,3,5,1,0 overlap on column 0
# 5,1,0,5,4 and 3,0,1,5,3 overlap on column 0
# 5,1,0,5,4 and 3,1,5,3,4 overlap on column 0
# 5,1,0,5,4 and 1,0,4,1,5 overlap on column 0
# 5,1,0,5,4 and 1,0,1,0,4 overlap on column 0
# 5,1,0,5,4 and 3,2,3,1,0 overlap on column 0
# 5,1,0,5,4 and 0,5,3,4,3 overlap on column 1
# 5,1,0,5,4 and 4,1,2,5,0 overlap on column 0
# 5,1,0,5,4 and 4,3,4,2,3 overlap on column 0
# 5,1,0,5,4 and 1,0,1,5,2 overlap on column 0
# 5,1,0,5,4 and 0,2,4,5,1 overlap on column 3
# 5,1,0,5,4 and 3,4,5,3,0 overlap on column 0
# 5,1,0,5,4 and 0,2,3,1,5 overlap on column 3
# 5,1,0,5,4 and 1,2,0,5,2 overlap on column 0
# 5,1,0,5,4 and 4,5,4,1,5 overlap on column 0
# 5,1,0,5,4 and 0,3,5,3,5 overlap on column 3
# 5,1,0,5,4 and 4,0,4,5,2 overlap on column 0
# 5,1,0,5,4 and 5,3,5,1,2 overlap on column 0
# 5,1,0,5,4 and 1,3,5,1,5 overlap on column 0
# 5,1,0,5,4 and 0,2,3,2,0 overlap on column 3
# 5,1,0,5,4 and 5,3,2,4,3 overlap on column 0
# 5,1,0,5,4 and 5,1,5,1,3 overlap on column 0
# 5,1,0,5,4 and 3,5,4,1,0 overlap on column 0
# 5,1,0,5,4 and 1,2,4,5,1 overlap on column 0
# 5,1,0,5,4 and 0,1,3,5,3 overlap on column 3
# 5,1,0,5,4 and 5,3,1,0,2 overlap on column 0
# 5,1,0,5,4 and 3,0,5,1,3 overlap on column 0
# 5,1,0,5,4 and 5,3,5,2,5 overlap on column 0
# 5,1,0,5,4 and 5,3,4,3,1 overlap on column 0
# 5,1,0,5,4 and 1,0,5,3,1 overlap on column 0
# 5,1,0,5,4 and 2,5,2,0,1 overlap on column 0
# 5,1,0,5,4 and 0,1,2,3,4 overlap on column 3
# 5,1,0,5,4 and 0,4,0,3,0 overlap on column 3
# 5,1,0,5,4 and 3,1,3,1,3 overlap on column 0
# 5,1,0,5,4 and 1,4,5,2,3 overlap on column 0
# 5,1,0,5,4 and 3,0,2,5,2 overlap on column 0
# 5,1,0,5,4 and 3,1,0,5,2 overlap on column 0
# 5,1,0,5,4 and 5,2,4,1,5 overlap on column 0
# 5,1,0,5,4 and 1,3,5,2,1 overlap on column 0
# 5,1,0,5,4 and 1,5,4,5,3 overlap on column 0
# 5,1,0,5,4 and 3,1,4,1,0 overlap on column 0
# 5,1,0,5,4 and 5,2,1,0,5 overlap on column 0
# 5,1,0,5,4 and 4,2,1,3,0 overlap on column 0
# 5,1,0,5,4 and 4,2,5,3,0 overlap on column 0
# 5,1,0,5,4 and 1,0,3,1,4 overlap on column 0
# 5,1,0,5,4 and 4,3,1,3,5 overlap on column 0
# 5,1,0,5,4 and 3,5,3,5,0 overlap on column 0
# 5,1,0,5,4 and 0,3,0,2,4 overlap on column 3
# 5,1,0,5,4 and 1,0,5,3,0 overlap on column 0
# 5,1,0,5,4 and 3,1,5,2,4 overlap on column 0
# 5,1,0,5,4 and 1,5,1,0,2 overlap on column 0
# ...
# 5,2,5,2,1 and 2,3,1,2,4 overlap on column 0
# 5,2,5,2,1 and 3,5,1,5,0 overlap on column 0
# 5,2,5,2,1 and 5,2,3,1,3 overlap on column 0
# 5,2,5,2,1 and 0,3,4,1,2 overlap on column 2
# 5,2,5,2,1 and 4,0,1,3,4 overlap on column 0
# 5,2,5,2,1 and 2,5,1,4,0 overlap on column 0
# 5,2,5,2,1 and 2,1,4,3,2 overlap on column 0
# 5,2,5,2,1 and 0,1,2,4,1 overlap on column 2
# 5,2,5,2,1 and 0,1,4,0,3 overlap on column 2
# 5,2,5,2,1 and 1,5,3,0,4 overlap on column 0
# 5,2,5,2,1 and 2,4,0,2,0 overlap on column 0
# 5,2,5,2,1 and 3,5,0,4,1 overlap on column 0
# 5,2,5,2,1 and 0,2,3,2,3 overlap on column 2
# 5,2,5,2,1 and 3,2,1,0,4 overlap on column 0
# 5,2,5,2,1 and 1,3,4,2,3 overlap on column 0
# 5,2,5,2,1 and 1,0,4,3,0 overlap on column 0
# 5,2,5,2,1 and 0,1,4,1,4 overlap on column 2
# 5,2,5,2,1 and 5,1,0,1,3 overlap on column 0
# 5,2,5,2,1 and 2,4,2,1,3 overlap on column 0
# 5,2,5,2,1 and 3,4,3,2,4 overlap on column 0
# 5,2,5,2,1 and 3,1,0,5,1 overlap on column 0
# 5,2,5,2,1 and 0,4,5,0,2 overlap on column 1
# 5,2,5,2,1 and 4,5,4,5,1 overlap on column 0
# 5,2,5,2,1 and 5,1,4,3,4 overlap on column 0
# 5,2,5,2,1 and 4,1,5,3,0 overlap on column 0
# 5,2,5,2,1 and 4,1,3,5,0 overlap on column 0
# 5,2,5,2,1 and 0,4,1,3,5 overlap on column 1
# 5,2,5,2,1 and 0,1,5,3,5 overlap on column 2
# 5,2,5,2,1 and 5,1,0,3,4 overlap on column 0
# 5,2,5,2,1 and 0,5,1,0,5 overlap on column 1
# 5,2,5,2,1 and 5,0,4,0,1 overlap on column 0
# 5,2,5,2,1 and 2,4,0,3,1 overlap on column 0
# 5,2,5,2,1 and 5,3,5,1,3 overlap on column 0
# 5,2,5,2,1 and 1,0,3,2,5 overlap on column 0
# 5,2,5,2,1 and 5,1,5,3,1 overlap on column 0
# 5,2,5,2,1 and 0,3,1,2,4 overlap on column 2
# 5,2,5,2,1 and 2,0,4,0,2 overlap on column 0
# 5,2,5,2,1 and 5,1,3,1,3 overlap on column 0
# 5,2,5,2,1 and 5,0,4,1,4 overlap on column 0
# 5,2,5,2,1 and 1,4,5,0,4 overlap on column 0
# 5,2,5,2,1 and 5,2,1,2,0 overlap on column 0
# 5,2,5,2,1 and 1,5,4,3,0 overlap on column 0
# 5,2,5,2,1 and 4,3,5,0,3 overlap on column 0
# 5,2,5,2,1 and 5,4,1,0,5 overlap on column 0
# 5,2,5,2,1 and 3,1,4,0,3 overlap on column 0
# 5,2,5,2,1 and 3,4,3,4,1 overlap on column 0
# 5,2,5,2,1 and 1,4,0,4,2 overlap on column 0
# 5,2,5,2,1 and 1,5,3,2,1 overlap on column 0
# 5,2,5,2,1 and 3,5,1,5,3 overlap on column 0
# 5,2,5,2,1 and 5,4,0,4,0 overlap on column 0
# 5,2,5,2,1 and 3,2,4,2,5 overlap on column 0
# 5,2,5,2,1 and 2,1,4,1,0 overlap on column 0
# 5,2,5,2,1 and 2,5,3,5,3 overlap on column 0
# 5,2,5,2,1 and 2,0,2,0,4 overlap on column 0
# 5,2,5,2,1 and 5,0,4,2,0 overlap on column 0
# 5,2,5,2,1 and 3,0,1,0,1 overlap on column 0
# 5,2,5,2,1 and 1,0,5,4,2 overlap on column 0
# 5,2,5,2,1 and 2,0,1,0,3 overlap on column 0
# 5,2,5,2,1 and 3,5,4,2,1 overlap on column 0
# 5,2,5,2,1 and 5,2,1,5,0 overlap on column 0
# 5,2,5,2,1 and 3,1,2,4,1 overlap on column 0
# 5,2,5,2,1 and 3,0,4,2,1 overlap on column 0
# 5,2,5,2,1 and 0,5,2,0,5 overlap on column 1
# 5,2,5,2,1 and 4,5,0,1,5 overlap on column 0
# 5,2,5,2,1 and 0,3,0,3,1 fit all columns
# 5,2,5,2,1 and 1,3,2,3,0 overlap on column 0
# 5,2,5,2,1 and 3,2,1,2,5 overlap on column 0
# 5,2,5,2,1 and 0,3,2,0,5 overlap on column 2
# 5,2,5,2,1 and 0,4,3,5,2 overlap on column 1
# 5,2,5,2,1 and 1,0,5,1,0 overlap on column 0
# 5,2,5,2,1 and 5,0,3,5,2 overlap on column 0
# 5,2,5,2,1 and 5,0,1,4,2 overlap on column 0
# 5,2,5,2,1 and 0,2,3,1,3 overlap on column 2
# 5,2,5,2,1 and 4,0,1,4,3 overlap on column 0
# 5,2,5,2,1 and 4,3,5,0,4 overlap on column 0
# 5,2,5,2,1 and 0,5,2,0,3 overlap on column 1
# 5,2,5,2,1 and 0,3,2,5,1 overlap on column 2
# 5,2,5,2,1 and 2,5,1,4,5 overlap on column 0
# 5,2,5,2,1 and 0,1,5,3,0 overlap on column 2
# 5,2,5,2,1 and 4,3,5,3,0 overlap on column 0
# 5,2,5,2,1 and 0,2,3,0,3 overlap on column 2
# 5,2,5,2,1 and 5,2,3,1,2 overlap on column 0
# 5,2,5,2,1 and 1,2,5,3,1 overlap on column 0
# 5,2,5,2,1 and 2,0,1,4,3 overlap on column 0
# 5,2,5,2,1 and 0,3,0,1,3 fit all columns
# 5,2,5,2,1 and 3,2,1,0,2 overlap on column 0
# 5,2,5,2,1 and 1,0,3,1,0 overlap on column 0
# 5,2,5,2,1 and 3,1,3,2,3 overlap on column 0
# 5,2,5,2,1 and 3,1,3,4,5 overlap on column 0
# 5,2,5,2,1 and 2,1,4,5,4 overlap on column 0
# 5,2,5,2,1 and 1,2,0,2,5 overlap on column 0
# 5,2,5,2,1 and 2,1,2,0,4 overlap on column 0
# 5,2,5,2,1 and 5,2,4,5,4 overlap on column 0
# 5,2,5,2,1 and 3,5,1,4,5 overlap on column 0
# 5,2,5,2,1 and 3,2,0,5,1 overlap on column 0
# 5,2,5,2,1 and 0,3,2,4,3 overlap on column 2
# 5,2,5,2,1 and 0,5,4,1,0 overlap on column 1
# 5,2,5,2,1 and 5,1,3,2,0 overlap on column 0
# 5,2,5,2,1 and 3,4,1,4,0 overlap on column 0
# 5,2,5,2,1 and 2,5,1,0,5 overlap on column 0
# 5,2,5,2,1 and 4,2,3,4,1 overlap on column 0
# 5,2,5,2,1 and 1,2,4,3,0 overlap on column 0
# 5,2,5,2,1 and 1,0,3,0,5 overlap on column 0
# 5,2,5,2,1 and 1,4,0,5,3 overlap on column 0
# 5,2,5,2,1 and 4,0,2,5,1 overlap on column 0
# 5,2,5,2,1 and 4,5,3,0,2 overlap on column 0
# 5,2,5,2,1 and 1,2,5,1,3 overlap on column 0
# 5,2,5,2,1 and 1,3,2,3,4 overlap on column 0
# 5,2,5,2,1 and 0,2,3,5,2 overlap on column 2
# 5,2,5,2,1 and 4,1,3,0,2 overlap on column 0
# 5,2,5,2,1 and 3,5,3,4,2 overlap on column 0
# 5,2,5,2,1 and 2,0,3,0,3 overlap on column 0
# 5,2,5,2,1 and 3,5,0,3,5 overlap on column 0
# 2,3,5,2,0 and 5,1,2,1,4 overlap on column 0
# 2,3,5,2,0 and 2,5,2,1,3 overlap on column 1
# 2,3,5,2,0 and 0,5,3,5,4 overlap on column 1
# 2,3,5,2,0 and 0,5,1,4,3 overlap on column 1
# 2,3,5,2,0 and 3,4,5,3,5 overlap on column 1
# 2,3,5,2,0 and 5,3,4,2,0 overlap on column 0
# 2,3,5,2,0 and 0,3,4,2,5 overlap on column 1
# 2,3,5,2,0 and 1,4,0,5,1 overlap on column 1
# 2,3,5,2,0 and 0,1,0,1,4 fit all columns
# 2,3,5,2,0 and 1,0,1,0,5 overlap on column 2
# 2,3,5,2,0 and 3,1,3,4,3 overlap on column 2
# 2,3,5,2,0 and 3,1,0,3,2 fit all columns
# 2,3,5,2,0 and 4,5,0,2,3 overlap on column 0
# 2,3,5,2,0 and 0,3,1,0,1 overlap on column 1
# 2,3,5,2,0 and 5,1,5,0,2 overlap on column 0
# 2,3,5,2,0 and 5,1,5,2,0 overlap on column 0
# 2,3,5,2,0 and 3,4,1,5,4 overlap on column 1
# 2,3,5,2,0 and 5,1,4,5,3 overlap on column 0
# 2,3,5,2,0 and 4,5,4,0,1 overlap on column 0
# 2,3,5,2,0 and 2,3,2,5,4 overlap on column 1
# 2,3,5,2,0 and 1,2,0,4,2 overlap on column 3
# 2,3,5,2,0 and 5,4,3,5,2 overlap on column 0
# 2,3,5,2,0 and 1,5,0,2,1 overlap on column 1
# 2,3,5,2,0 and 0,2,0,3,1 fit all columns
# 2,3,5,2,0 and 2,3,1,5,1 overlap on column 1
# 2,3,5,2,0 and 3,2,5,3,1 overlap on column 2
# 2,3,5,2,0 and 5,0,5,3,2 overlap on column 0
# 2,3,5,2,0 and 0,2,3,4,1 overlap on column 2
# 2,3,5,2,0 and 4,5,4,5,4 overlap on column 0
# 2,3,5,2,0 and 4,3,2,0,3 overlap on column 0
# 2,3,5,2,0 and 3,2,5,0,2 overlap on column 2
# 2,3,5,2,0 and 5,1,2,5,3 overlap on column 0
# 2,3,5,2,0 and 5,4,1,4,0 overlap on column 0
# 2,3,5,2,0 and 1,0,5,3,2 overlap on column 2
# 2,3,5,2,0 and 4,3,5,4,3 overlap on column 0
# 2,3,5,2,0 and 2,5,4,0,3 overlap on column 1
# 2,3,5,2,0 and 0,2,5,0,2 overlap on column 2
# 2,3,5,2,0 and 4,0,5,1,0 overlap on column 0
# 2,3,5,2,0 and 1,2,4,5,3 overlap on column 2
# 2,3,5,2,0 and 3,1,3,5,3 overlap on column 2
# 2,3,5,2,0 and 3,2,4,1,2 overlap on column 2
# 2,3,5,2,0 and 2,4,0,3,0 overlap on column 1
# 2,3,5,2,0 and 3,5,0,4,0 overlap on column 1
# 2,3,5,2,0 and 3,5,4,5,2 overlap on column 1
# 2,3,5,2,0 and 1,2,5,2,0 overlap on column 2
# 2,3,5,2,0 and 4,0,4,1,2 overlap on column 0
# 2,3,5,2,0 and 3,4,0,3,0 overlap on column 1
# 2,3,5,2,0 and 5,1,5,4,3 overlap on column 0
# 2,3,5,2,0 and 4,5,4,5,2 overlap on column 0
# 2,3,5,2,0 and 4,2,0,3,5 overlap on column 0
# 2,3,5,2,0 and 2,3,4,5,2 overlap on column 1
# 2,3,5,2,0 and 3,4,1,5,2 overlap on column 1
# 2,3,5,2,0 and 0,1,3,2,0 overlap on column 2
# 2,3,5,2,0 and 4,3,5,1,0 overlap on column 0
# 2,3,5,2,0 and 3,0,1,5,3 overlap on column 2
# 2,3,5,2,0 and 3,1,5,3,4 overlap on column 2
# 2,3,5,2,0 and 1,0,4,1,5 overlap on column 2
# 2,3,5,2,0 and 1,0,1,0,4 overlap on column 2
# 2,3,5,2,0 and 3,2,3,1,0 overlap on column 2
# 2,3,5,2,0 and 0,5,3,4,3 overlap on column 1
# 2,3,5,2,0 and 4,1,2,5,0 overlap on column 0
# 2,3,5,2,0 and 4,3,4,2,3 overlap on column 0
# 2,3,5,2,0 and 1,0,1,5,2 overlap on column 2
# 2,3,5,2,0 and 0,2,4,5,1 overlap on column 2
# 2,3,5,2,0 and 3,4,5,3,0 overlap on column 1
# 2,3,5,2,0 and 0,2,3,1,5 overlap on column 2
# 2,3,5,2,0 and 1,2,0,5,2 overlap on column 3
# 2,3,5,2,0 and 4,5,4,1,5 overlap on column 0
# 2,3,5,2,0 and 0,3,5,3,5 overlap on column 1
# 2,3,5,2,0 and 4,0,4,5,2 overlap on column 0
# 2,3,5,2,0 and 5,3,5,1,2 overlap on column 0
# 2,3,5,2,0 and 1,3,5,1,5 overlap on column 1
# 2,3,5,2,0 and 0,2,3,2,0 overlap on column 2
# 2,3,5,2,0 and 5,3,2,4,3 overlap on column 0
# 2,3,5,2,0 and 5,1,5,1,3 overlap on column 0
# 2,3,5,2,0 and 3,5,4,1,0 overlap on column 1
# 2,3,5,2,0 and 1,2,4,5,1 overlap on column 2
# 2,3,5,2,0 and 0,1,3,5,3 overlap on column 2
# 2,3,5,2,0 and 5,3,1,0,2 overlap on column 0
# 2,3,5,2,0 and 3,0,5,1,3 overlap on column 2
# 2,3,5,2,0 and 5,3,5,2,5 overlap on column 0
# 2,3,5,2,0 and 5,3,4,3,1 overlap on column 0
# 2,3,5,2,0 and 1,0,5,3,1 overlap on column 2
# 2,3,5,2,0 and 2,5,2,0,1 overlap on column 1
# 2,3,5,2,0 and 0,1,2,3,4 overlap on column 2
# 2,3,5,2,0 and 0,4,0,3,0 overlap on column 1
# 2,3,5,2,0 and 3,1,3,1,3 overlap on column 2
# 2,3,5,2,0 and 1,4,5,2,3 overlap on column 1
# 2,3,5,2,0 and 3,0,2,5,2 overlap on column 2
# 2,3,5,2,0 and 3,1,0,5,2 overlap on column 3
# 2,3,5,2,0 and 5,2,4,1,5 overlap on column 0
# 2,3,5,2,0 and 1,3,5,2,1 overlap on column 1
# 2,3,5,2,0 and 1,5,4,5,3 overlap on column 1
# 2,3,5,2,0 and 3,1,4,1,0 overlap on column 2
# 2,3,5,2,0 and 5,2,1,0,5 overlap on column 0
# 2,3,5,2,0 and 4,2,1,3,0 overlap on column 0
# 2,3,5,2,0 and 4,2,5,3,0 overlap on column 0
# 2,3,5,2,0 and 1,0,3,1,4 overlap on column 2
# 2,3,5,2,0 and 4,3,1,3,5 overlap on column 0
# 2,3,5,2,0 and 3,5,3,5,0 overlap on column 1
# 2,3,5,2,0 and 0,3,0,2,4 overlap on column 1
# 2,3,5,2,0 and 1,0,5,3,0 overlap on column 2
# 2,3,5,2,0 and 3,1,5,2,4 overlap on column 2
# 2,3,5,2,0 and 1,5,1,0,2 overlap on column 1
# 2,3,5,2,0 and 0,5,1,4,1 overlap on column 1
# 2,3,5,2,0 and 2,5,0,2,4 overlap on column 1
# 2,3,5,2,0 and 3,2,4,2,3 overlap on column 2
# 2,3,5,2,0 and 1,5,1,2,5 overlap on column 1
# 2,3,5,2,0 and 0,5,4,2,1 overlap on column 1
# 2,3,5,2,0 and 5,3,0,3,1 overlap on column 0
# 2,3,5,2,0 and 5,1,4,2,0 overlap on column 0
# 2,3,5,2,0 and 3,4,3,1,2 overlap on column 1
# 2,3,5,2,0 and 0,1,5,1,0 overlap on column 2
# 2,3,5,2,0 and 5,4,5,3,0 overlap on column 0
# 2,3,5,2,0 and 2,1,0,4,0 overlap on column 3
# 2,3,5,2,0 and 4,5,1,2,1 overlap on column 0
# 2,3,5,2,0 and 2,5,1,5,0 overlap on column 1
# 2,3,5,2,0 and 0,1,2,1,3 overlap on column 2
# 2,3,5,2,0 and 4,1,5,3,4 overlap on column 0
# 2,3,5,2,0 and 0,5,3,1,4 overlap on column 1
# 2,3,5,2,0 and 4,1,5,0,1 overlap on column 0
# 2,3,5,2,0 and 3,5,2,4,5 overlap on column 1
# 2,3,5,2,0 and 3,5,3,5,4 overlap on column 1
# 2,3,5,2,0 and 1,5,1,0,1 overlap on column 1
# 2,3,5,2,0 and 1,3,0,2,1 overlap on column 1
# 2,3,5,2,0 and 5,0,3,1,4 overlap on column 0
# 2,3,5,2,0 and 4,1,5,3,2 overlap on column 0
# 2,3,5,2,0 and 4,2,3,4,5 overlap on column 0
# 2,3,5,2,0 and 3,2,0,2,0 fit all columns
# 2,3,5,2,0 and 3,5,1,2,3 overlap on column 1
# 2,3,5,2,0 and 1,2,4,1,3 overlap on column 2
# 2,3,5,2,0 and 1,5,0,3,4 overlap on column 1
# 2,3,5,2,0 and 3,1,0,3,5 fit all columns
# 2,3,5,2,0 and 5,3,4,2,3 overlap on column 0
# 2,3,5,2,0 and 1,5,2,5,2 overlap on column 1
# 2,3,5,2,0 and 4,5,0,3,4 overlap on column 0
# 2,3,5,2,0 and 4,2,3,4,2 overlap on column 0
# 2,3,5,2,0 and 2,3,1,2,4 overlap on column 1
# 2,3,5,2,0 and 3,5,1,5,0 overlap on column 1
# 2,3,5,2,0 and 5,2,3,1,3 overlap on column 0
# 2,3,5,2,0 and 0,3,4,1,2 overlap on column 1
# 2,3,5,2,0 and 4,0,1,3,4 overlap on column 0
# 2,3,5,2,0 and 2,5,1,4,0 overlap on column 1
# 2,3,5,2,0 and 2,1,4,3,2 overlap on column 2
# 2,3,5,2,0 and 0,1,2,4,1 overlap on column 2
# 2,3,5,2,0 and 0,1,4,0,3 overlap on column 2
# 2,3,5,2,0 and 1,5,3,0,4 overlap on column 1
# 2,3,5,2,0 and 2,4,0,2,0 overlap on column 1
# 2,3,5,2,0 and 3,5,0,4,1 overlap on column 1
# 2,3,5,2,0 and 0,2,3,2,3 overlap on column 2
# 2,3,5,2,0 and 3,2,1,0,4 overlap on column 2
# 2,3,5,2,0 and 1,3,4,2,3 overlap on column 1
# 2,3,5,2,0 and 1,0,4,3,0 overlap on column 2
# 2,3,5,2,0 and 0,1,4,1,4 overlap on column 2
# 2,3,5,2,0 and 5,1,0,1,3 overlap on column 0
# 2,3,5,2,0 and 2,4,2,1,3 overlap on column 1
# 2,3,5,2,0 and 3,4,3,2,4 overlap on column 1
# 2,3,5,2,0 and 3,1,0,5,1 overlap on column 3
# 2,3,5,2,0 and 0,4,5,0,2 overlap on column 1
# 2,3,5,2,0 and 4,5,4,5,1 overlap on column 0
# 2,3,5,2,0 and 5,1,4,3,4 overlap on column 0
# 2,3,5,2,0 and 4,1,5,3,0 overlap on column 0
# 2,3,5,2,0 and 4,1,3,5,0 overlap on column 0
# 2,3,5,2,0 and 0,4,1,3,5 overlap on column 1
# 2,3,5,2,0 and 0,1,5,3,5 overlap on column 2
# 2,3,5,2,0 and 5,1,0,3,4 overlap on column 0
# 2,3,5,2,0 and 0,5,1,0,5 overlap on column 1
# 2,3,5,2,0 and 5,0,4,0,1 overlap on column 0
# 2,3,5,2,0 and 2,4,0,3,1 overlap on column 1
# 2,3,5,2,0 and 5,3,5,1,3 overlap on column 0
# 2,3,5,2,0 and 1,0,3,2,5 overlap on column 2
# 2,3,5,2,0 and 5,1,5,3,1 overlap on column 0
# 2,3,5,2,0 and 0,3,1,2,4 overlap on column 1
# 2,3,5,2,0 and 2,0,4,0,2 overlap on column 2
# 2,3,5,2,0 and 5,1,3,1,3 overlap on column 0
# 2,3,5,2,0 and 5,0,4,1,4 overlap on column 0
# 2,3,5,2,0 and 1,4,5,0,4 overlap on column 1
# 2,3,5,2,0 and 5,2,1,2,0 overlap on column 0
# 2,3,5,2,0 and 1,5,4,3,0 overlap on column 1
# 2,3,5,2,0 and 4,3,5,0,3 overlap on column 0
# 2,3,5,2,0 and 5,4,1,0,5 overlap on column 0
# 2,3,5,2,0 and 3,1,4,0,3 overlap on column 2
# 2,3,5,2,0 and 3,4,3,4,1 overlap on column 1
# 2,3,5,2,0 and 1,4,0,4,2 overlap on column 1
# 2,3,5,2,0 and 1,5,3,2,1 overlap on column 1
# 2,3,5,2,0 and 3,5,1,5,3 overlap on column 1
# 2,3,5,2,0 and 5,4,0,4,0 overlap on column 0
# 2,3,5,2,0 and 3,2,4,2,5 overlap on column 2
# 2,3,5,2,0 and 2,1,4,1,0 overlap on column 2
# 2,3,5,2,0 and 2,5,3,5,3 overlap on column 1
# 2,3,5,2,0 and 2,0,2,0,4 overlap on column 2
# 2,3,5,2,0 and 5,0,4,2,0 overlap on column 0
# 2,3,5,2,0 and 3,0,1,0,1 overlap on column 2
# 2,3,5,2,0 and 1,0,5,4,2 overlap on column 2
# 2,3,5,2,0 and 2,0,1,0,3 overlap on column 2
# 2,3,5,2,0 and 3,5,4,2,1 overlap on column 1
# 2,3,5,2,0 and 5,2,1,5,0 overlap on column 0
# 2,3,5,2,0 and 3,1,2,4,1 overlap on column 2
# 2,3,5,2,0 and 3,0,4,2,1 overlap on column 2
# 2,3,5,2,0 and 0,5,2,0,5 overlap on column 1
# 2,3,5,2,0 and 4,5,0,1,5 overlap on column 0
# 2,3,5,2,0 and 0,3,0,3,1 overlap on column 1
# 2,3,5,2,0 and 1,3,2,3,0 overlap on column 1
# 2,3,5,2,0 and 3,2,1,2,5 overlap on column 2
# 2,3,5,2,0 and 0,3,2,0,5 overlap on column 1
# 2,3,5,2,0 and 0,4,3,5,2 overlap on column 1
# 2,3,5,2,0 and 1,0,5,1,0 overlap on column 2
# 2,3,5,2,0 and 5,0,3,5,2 overlap on column 0
# 2,3,5,2,0 and 5,0,1,4,2 overlap on column 0
# 2,3,5,2,0 and 0,2,3,1,3 overlap on column 2
# 2,3,5,2,0 and 4,0,1,4,3 overlap on column 0
# 2,3,5,2,0 and 4,3,5,0,4 overlap on column 0
# 2,3,5,2,0 and 0,5,2,0,3 overlap on column 1
# 2,3,5,2,0 and 0,3,2,5,1 overlap on column 1
# 2,3,5,2,0 and 2,5,1,4,5 overlap on column 1
# 2,3,5,2,0 and 0,1,5,3,0 overlap on column 2
# 2,3,5,2,0 and 4,3,5,3,0 overlap on column 0
# 2,3,5,2,0 and 0,2,3,0,3 overlap on column 2
# 2,3,5,2,0 and 5,2,3,1,2 overlap on column 0
# 2,3,5,2,0 and 1,2,5,3,1 overlap on column 2
# 2,3,5,2,0 and 2,0,1,4,3 overlap on column 2
# 2,3,5,2,0 and 0,3,0,1,3 overlap on column 1
# 2,3,5,2,0 and 3,2,1,0,2 overlap on column 2
# 2,3,5,2,0 and 1,0,3,1,0 overlap on column 2
# 2,3,5,2,0 and 3,1,3,2,3 overlap on column 2
# 2,3,5,2,0 and 3,1,3,4,5 overlap on column 2
# 2,3,5,2,0 and 2,1,4,5,4 overlap on column 2
# 2,3,5,2,0 and 1,2,0,2,5 fit all columns
# 2,3,5,2,0 and 2,1,2,0,4 overlap on column 2
# 2,3,5,2,0 and 5,2,4,5,4 overlap on column 0
# 2,3,5,2,0 and 3,5,1,4,5 overlap on column 1
# 2,3,5,2,0 and 3,2,0,5,1 overlap on column 3
# 2,3,5,2,0 and 0,3,2,4,3 overlap on column 1
# 2,3,5,2,0 and 0,5,4,1,0 overlap on column 1
# 2,3,5,2,0 and 5,1,3,2,0 overlap on column 0
# 2,3,5,2,0 and 3,4,1,4,0 overlap on column 1
# 2,3,5,2,0 and 2,5,1,0,5 overlap on column 1
# 2,3,5,2,0 and 4,2,3,4,1 overlap on column 0
# 2,3,5,2,0 and 1,2,4,3,0 overlap on column 2
# 2,3,5,2,0 and 1,0,3,0,5 overlap on column 2
# 2,3,5,2,0 and 1,4,0,5,3 overlap on column 1
# 2,3,5,2,0 and 4,0,2,5,1 overlap on column 0
# 2,3,5,2,0 and 4,5,3,0,2 overlap on column 0
# 2,3,5,2,0 and 1,2,5,1,3 overlap on column 2
# 2,3,5,2,0 and 1,3,2,3,4 overlap on column 1
# 2,3,5,2,0 and 0,2,3,5,2 overlap on column 2
# 2,3,5,2,0 and 4,1,3,0,2 overlap on column 0
# 2,3,5,2,0 and 3,5,3,4,2 overlap on column 1
# 2,3,5,2,0 and 2,0,3,0,3 overlap on column 2
# 2,3,5,2,0 and 3,5,0,3,5 overlap on column 1
# $VAR1 = 3317;
#
# [time] 1 seconds
# 1

# %%
say post_answer('2024/day/25/answer', 1, $res);
# Out:
# <!DOCTYPE html>
# <html lang="en-us">
# <head>
# <meta charset="utf-8"/>
# <title>Day 25 - Advent of Code 2024</title>
# <link rel="stylesheet" type="text/css" href="/static/style.css?31"/>
# <link rel="stylesheet alternate" type="text/css" href="/static/highcontrast.css?1" title="High Contrast"/>
# <link rel="shortcut icon" href="/favicon.png"/>
# <script>window.addEventListener('click', function(e,s,r){if(e.target.nodeName==='CODE'&&e.detail===3){s=window.getSelection();s.removeAllRanges();r=document.createRange();r.selectNodeContents(e.target);s.addRange(r);}});</script>
# </head><!--
#
#
#
#
# Oh, hello!  Funny seeing you here.
#
# I appreciate your enthusiasm, but you aren't going to find much down here.
# There certainly aren't clues to any of the puzzles.  The best surprises don't
# even appear in the source until you unlock them for real.
#
# Please be careful with automated requests; I'm not a massive company, and I can
# only take so much traffic.  Please be considerate so that everyone gets to play.
#
# If you're curious about how Advent of Code works, it's running on some custom
# Perl code. Other than a few integrations (auth, analytics, social media), I
# built the whole thing myself, including the design, animations, prose, and all
# of the puzzles.
#
# The puzzles are most of the work; preparing a new calendar and a new set of
# puzzles each year takes all of my free time for 4-5 months. A lot of effort
# went into building this thing - I hope you're enjoying playing it as much as I
# enjoyed making it for you!
#
# If you'd like to hang out, I'm @was.tl on Bluesky, @ericwastl@hachyderm.io on
# Mastodon, and @ericwastl on Twitter.
#
# - Eric Wastl
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -->
# <body>
# <header><div><h1 class="title-global"><a href="/">Advent of Code</a></h1><nav><ul><li><a href="/2024/about">[About]</a></li><li><a href="/2024/events">[Events]</a></li><li><a href="https://cottonbureau.com/people/advent-of-code" target="_blank">[Shop]</a></li><li><a href="/2024/settings">[Settings]</a></li><li><a href="/2024/auth/logout">[Log Out]</a></li></ul></nav><div class="user">mirror12k <span class="star-count">49*</span></div></div><div><h1 class="title-event">&nbsp;&nbsp;<span class="title-event-wrap">{:year </span><a href="/2024">2024</a><span class="title-event-wrap">}</span></h1><nav><ul><li><a href="/2024">[Calendar]</a></li><li><a href="/2024/support">[AoC++]</a></li><li><a href="/2024/sponsors">[Sponsors]</a></li><li><a href="/2024/leaderboard">[Leaderboard]</a></li><li><a href="/2024/stats">[Stats]</a></li></ul></nav></div></header>
#
# <div id="sidebar">
# <div id="sponsor"><div class="quiet">Our <a href="/2024/sponsors">sponsors</a> help make Advent of Code possible:</div><div class="sponsor"><a href="/2024/sponsors/redirect?url=https%3A%2F%2Fwww%2Erijksorganisatieodi%2Enl%2Frijks%2Dict%2Dgilde" target="_blank" onclick="if(ga)ga('send','event','sponsor','sidebar',this.href);" rel="noopener">Rijks ICT Gilde</a> - Tech ambtenaren voor het Nederland van morgen!</div></div>
# </div><!--/sidebar-->
#
# <main>
# <article><p>That's the right answer!  You are <span class="day-success">one gold star</span> closer to finding the Chief Historian. <a href="/2024/day/25#part2">[Continue to Part Two]</a></p></article>
# </main>
#
# <!-- ga -->
# <script>
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# ga('create', 'UA-69522494-1', 'auto');
# ga('set', 'anonymizeIp', true);
# ga('send', 'pageview');
# </script>
# <!-- /ga -->
# </body>
# </html>
# 1
